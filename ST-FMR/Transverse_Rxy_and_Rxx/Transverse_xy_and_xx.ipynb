# %%
# Sample SSN095 FCB(4)/Pt(3)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis



Folder_SSN101 = r".\\SSN095\\Angular_transverse"
stfmr = STFMR(folder=Folder_SSN101, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=4e-9, d_NM=15e-9, Width=20e-6, Length=20e-6)

stfmr.transverse_scan()
# stfmr.average_fitparams(folder=r".\\SSN138\\Angular_longitudinal", plot=True)
stfmr.angular_scan_transverse2(method='Average_fitparams')

# stfmr.plot_traces()
# stfmr.average_fitparams()
# stfmr.analyse_folder(False)
# stfmr.plot_Kittel()
# stfmr.plot_linewidth()
# Out:
# .\\SSN095\\Angular_transverse\Angular_transverse\fit_results_average_posB.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 21
#      19 stfmr.transverse_scan()
#      20 # stfmr.average_fitparams(folder=r".\\SSN138\\Angular_longitudinal", plot=True)
# ---> 21 stfmr.angular_scan_transverse2(method='Average_fitparams')
#      23 # stfmr.plot_traces()
#      24 # stfmr.average_fitparams()
#      25 # stfmr.analyse_folder(False)
#      26 # stfmr.plot_Kittel()
#      27 # stfmr.plot_linewidth()
#
# File c:\git\MasterProject\ST-FMR\Analysis.py:788, in STFMR.angular_scan_transverse2(self, method)
#     785 resultspath_longitudinal_avg = os.path.join(longitudinal_folder, "Averaged_Traces_posB", "fit_results_average_posB.csv")
#     787 if not os.path.exists(resultspath_transverse):
# --> 788     self.average_fitparams(folder=transverse_folder, plot=False)
# ...

# %%
# Sample SSN101 FCB(4)/Pt(3)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis



Folder_SSN101 = r".\\SSN101\\Angular_transverse"
stfmr = STFMR(folder=Folder_SSN101, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=4e-9, d_NM=5e-9, Width=20e-6, Length=20e-6)
stfmr.transverse_scan(method='Average_fitparams')

# stfmr.average_fitparams(folder=r".\\SSN138\\Angular_longitudinal", plot=True)
stfmr.angular_scan_transverse2(method='Average_fitparams')

# stfmr.plot_traces()
# stfmr.average_fitparams()
# stfmr.analyse_folder(False)
# stfmr.plot_Kittel()
# stfmr.plot_linewidth()
# Out:
# .\\SSN101\\Angular_transverse\Angular_transverse\fit_results_average_posB.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 21
#      18 stfmr.transverse_scan(method='Average_fitparams')
#      20 # stfmr.average_fitparams(folder=r".\\SSN138\\Angular_longitudinal", plot=True)
# ---> 21 stfmr.angular_scan_transverse2(method='Average_fitparams')
#      23 # stfmr.plot_traces()
#      24 # stfmr.average_fitparams()
#      25 # stfmr.analyse_folder(False)
#      26 # stfmr.plot_Kittel()
#      27 # stfmr.plot_linewidth()
#
# File c:\git\MasterProject\ST-FMR\Analysis.py:788, in STFMR.angular_scan_transverse2(self, method)
#     785 resultspath_longitudinal_avg = os.path.join(longitudinal_folder, "Averaged_Traces_posB", "fit_results_average_posB.csv")
#     787 if not os.path.exists(resultspath_transverse):
# ...

# %%
# Sample SSN138 FCB(4)/Pt(3)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis



Folder_SSN138 = r".\\SSN138"
stfmr = STFMR(folder=Folder_SSN138, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=4e-9, d_NM=3e-9, Width=20e-6, Length=20e-6)

# stfmr.average_fitparams(folder=r".\\SSN138\\Angular_longitudinal", plot=True)
stfmr.angular_scan_transverse2(method='Average_fitparams')

# stfmr.plot_traces()
# stfmr.average_fitparams()
# stfmr.analyse_folder(False)
# stfmr.plot_Kittel()
# stfmr.plot_linewidth()
# Out:
# ---- Angular fitting results ----
#
# Longitudinal mixing voltage:
#   Vs (symmetric):
#     S_XX_AMR_art = -44.39 ± 0.51
#     S_XX_FL      = 1.937 ± 0.36
#   Va (antisymmetric):
#     A_XX_AMR     = -57.56 ± 1.5
#     A_XX_DL      = -0.2962 ± 1.1
# Transverse mixing voltage:
#   Vs (symmetric):
#     S_XY_PHE_art  = 9.345 ± 0.19
#     S_XY_AHE_art  = -15.71 ± 0.14
#     S_XY_FL_PHE   = 0.02285 ± 0.097
#     S_XY_DL_AHE   = -0.4023 ± 0.069
#   Va (antisymmetric):
#     A_XY_PHE      = 9.627 ± 0.22
#     A_XY_AHE      = 18.02 ± 0.16
#     A_XY_DL_PHE      = 0.4595 ± 0.11
#     A_XY_FL_AHE      = -0.5556 ± 0.077
# Longtidunal xi: 0.06905501714730736 ± 0.004208131709297535. Meff: 1.2407446208252528 ± [0.01395139] T
# Transverse xi: -0.052127192394652785 ± 0.016895506975708224. Meff: 1.2216775592736113 ± [0.00891431] T
# 1.___Magnetization Dyanamics
# Meff average: 1.231211090049432 ± 0.008914308915219011
# Results Resonance Field:
# ...

# %%
# Sample SSN139 FCB(4)/Pt(7)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN139 = r".\\SSN139"

stfmr = STFMR(folder=Folder_SSN139, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=4e-9, d_NM=7e-9, Width=20e-6, Length=20e-6)

# stfmr.average_fitparams(plot=False)
stfmr.angular_scan_transverse2(method='Average_measurements')

# stfmr.plot_traces()
# stfmr.average_fitparams()
# stfmr.analyse_folder(False)
# stfmr.plot_Kittel()
# stfmr.plot_linewidth()
# Out:
# ---- Angular fitting results ----
#
# Longitudinal mixing voltage:
#   Vs (symmetric):
#     S_XX_AMR_art = -3.449 ± 1
#     S_XX_FL      = -0.8472 ± 0.73
#   Va (antisymmetric):
#     A_XX_AMR     = -23.26 ± 1.4
#     A_XX_DL      = 0.8514 ± 0.98
# Transverse mixing voltage:
#   Vs (symmetric):
#     S_XY_PHE_art  = 2.977 ± 0.21
#     S_XY_AHE_art  = -26.2 ± 0.15
#     S_XY_FL_PHE   = -0.2719 ± 0.1
#     S_XY_DL_AHE   = -0.1423 ± 0.074
#   Va (antisymmetric):
#     A_XY_PHE      = 18.42 ± 0.19
#     A_XY_AHE      = 10.72 ± 0.14
#     A_XY_DL_PHE      = 0.2678 ± 0.094
#     A_XY_FL_AHE      = 0.1253 ± 0.067
# Longtidunal xi: -0.004720040572976515 ± 0.008394213435387793. Meff: 1.25758970614035 ± [0.01104806] T
# Transverse xi: -0.37637615619549847 ± 0.07624903301222995. Meff: 1.2317288442774228 ± [0.00897778] T
# 1.___Magnetization Dyanamics
# Meff average: 1.2446592752088863 ± 0.008977781580781611
# Results Resonance Field:
# ...

# %%
# Sample SSN141 FCB(4)/Pt(9)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis
# Folder_SSN143 = r".\\SSN141\\Angular_longitudinal\\FrequencyScan"
# stfmr = STFMR(folder=Folder_SSN143, voltage_unit='uV', used_fields='Pos', Ms=1.26, d_FM=4e-9, d_NM=13e-9, Width=20e-6, Length=20e-6)
# stfmr.average_fitparams(plot=True)
Folder_SSN141 = r".\\SSN141"

stfmr = STFMR(folder=Folder_SSN141, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=4e-9, d_NM=9e-9, Width=20e-6, Length=20e-6)

# stfmr.average_fitparams(plot=False)
stfmr.angular_scan_transverse2(method='Average_measurements')

# stfmr.plot_traces()
# stfmr.average_fitparams()
# stfmr.analyse_folder(False)
# stfmr.plot_Kittel()
# stfmr.plot_linewidth()
# Out:
# ---- Angular fitting results ----
#
# Longitudinal mixing voltage:
#   Vs (symmetric):
#     S_XX_AMR_art = -4.027 ± 0.14
#     S_XX_FL      = 0.1385 ± 0.098
#   Va (antisymmetric):
#     A_XX_AMR     = -62.96 ± 0.28
#     A_XX_DL      = -0.1851 ± 0.2
# Transverse mixing voltage:
#   Vs (symmetric):
#     S_XY_PHE_art  = 2.723 ± 0.15
#     S_XY_AHE_art  = -25.5 ± 0.11
#     S_XY_FL_PHE   = 0.03689 ± 0.076
#     S_XY_DL_AHE   = -0.1185 ± 0.054
#   Va (antisymmetric):
#     A_XY_PHE      = 17.52 ± 0.21
#     A_XY_AHE      = 7.238 ± 0.15
#     A_XY_DL_PHE      = 0.1094 ± 0.11
#     A_XY_FL_AHE      = -0.02813 ± 0.076
# Longtidunal xi: 0.007466025207192589 ± 0.004717369763363778. Meff: 1.2068756005023187 ± [0.0057082] T
# Transverse xi: -0.7817133434419169 ± 0.08496265667007713. Meff: 1.2118713474251348 ± [0.00165619] T
# 1.___Magnetization Dyanamics
# Meff average: 1.2093734739637267 ± 0.0016561885739601345
# Results Resonance Field:
# ...

# %%
# Sample SSN143 FCB(4)/Pt(13)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN143 = r".\\SSN143"
stfmr = STFMR(folder=Folder_SSN143, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=4e-9, d_NM=13e-9, Width=20e-6, Length=20e-6)
stfmr.angular_scan_transverse2(method='Average_measurements')



# stfmr.plot_traces()
# stfmr.average_fitparams()
# stfmr.analyse_folder(False)
# stfmr.plot_Kittel()
# stfmr.plot_linewidth()
# Out:
# ---- Angular fitting results ----
#
# Longitudinal mixing voltage:
#   Vs (symmetric):
#     S_XX_AMR_art = 2.212 ± 0.31
#     S_XX_FL      = -0.4694 ± 0.22
#   Va (antisymmetric):
#     A_XX_AMR     = -13.6 ± 0.27
#     A_XX_DL      = 0.2074 ± 0.19
# Transverse mixing voltage:
#   Vs (symmetric):
#     S_XY_PHE_art  = -0.7446 ± 0.16
#     S_XY_AHE_art  = -20.63 ± 0.11
#     S_XY_FL_PHE   = -0.1454 ± 0.079
#     S_XY_DL_AHE   = 0.04047 ± 0.056
#   Va (antisymmetric):
#     A_XY_PHE      = 15.11 ± 0.15
#     A_XY_AHE      = 3.835 ± 0.11
#     A_XY_DL_PHE      = 0.03517 ± 0.077
#     A_XY_FL_AHE      = 0.004007 ± 0.055
# Transverse xi: -1.167384316227205 ± 0.18781854704370438. Meff: 1.1598485053089782 ± [0.00402181] T
# 1.___Magnetization Dyanamics
# Meff average: 1.179924252654489 ± 0.004021813683185821
# Results Resonance Field:
# Transverse measurements, Hres: 94.79335040415552 ± 11.39947092277277
# Longitudinal measurements, Hres: 94.60575855127578 ± 2.544490585124909
#
# ...

# %%
# Sample SSN140 FCB(4)/Pt(18)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN140 = r".\\SSN140"


stfmr = STFMR(folder=Folder_SSN140, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=4e-9, d_NM=18e-9, Width=20e-6, Length=20e-6)

# stfmr.average_fitparams(plot=False)
stfmr.angular_scan_transverse2(method="Average_measurements")

# stfmr.plot_traces()
# stfmr.average_fitparams()
# stfmr.analyse_folder(False)
# stfmr.plot_Kittel()
# stfmr.plot_linewidth()
# Out:
# ---- Angular fitting results ----
#
# Longitudinal mixing voltage:
#   Vs (symmetric):
#     S_XX_AMR_art = 2.445 ± 0.16
#     S_XX_FL      = -0.2505 ± 0.11
#   Va (antisymmetric):
#     A_XX_AMR     = -8.739 ± 0.089
#     A_XX_DL      = 0.08973 ± 0.063
# Transverse mixing voltage:
#   Vs (symmetric):
#     S_XY_PHE_art  = -2.538 ± 0.049
#     S_XY_AHE_art  = -14.77 ± 0.035
#     S_XY_FL_PHE   = -0.03938 ± 0.024
#     S_XY_DL_AHE   = -0.03973 ± 0.017
#   Va (antisymmetric):
#     A_XY_PHE      = 10.79 ± 0.091
#     A_XY_AHE      = 2.069 ± 0.065
#     A_XY_DL_PHE      = 0.03208 ± 0.045
#     A_XY_FL_AHE      = -0.009342 ± 0.032
# Longtidunal xi: -0.16310977339037935 ± 0.02668562189484508. Meff: 1.2276337749817516 ± [0.00806603] T
# Transverse xi: -2.7872234108780254 ± 0.5245960751624243. Meff: 1.2304330915323878 ± [0.00839394] T
# 1.___Magnetization Dyanamics
# Meff average: 1.2290334332570696 ± 0.0083939431412571
# Results Resonance Field:
# ...

# %% [markdown]
# 0.4171251296277287 0.036720069516511494
# 0.1646557889946249 0.015787699855193287
# 0.28404502203221105 0.01632436814400589
# 0.44220046869188695 0.011129047887602278

# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.array([3, 5, 7, 9, 13, 15, 18])
tt = np.array([ 7, 9, 13, 18])

values = np.array([
    0.4171251296277287,
    2.884570181010398,
    4.292624987989247,
    4.772018079008526
])

errors = np.array([
    0.036720069516511494,
    0.015787699855193287,
    0.01632436814400589,
    0.011129047887602278
])
ArtifactVoltage_PHE = np.array([0, 0, -0.33035330286134157, -0.045817677157164775, -0.3155801362532063,-0,-0.5460537506817336 ])
ArtifactVoltage_PHE_err = np.array([0, 0, -0.03499747447913025, -0.004362159229058996, -0.01894953739137728 ,-0.013212381797178784,-0.014091459180571872])

ArtifactVoltage_AMR = np.array([0.09042071605106773,0.15234268101028603 ,0.19926250208864596, 0.14506467824352148, 0.31643515605105343,0.3269450234471539, 0.3934388612362903])
ArtifactVoltage_AMR_err = np.array([0.007993641955864928,  0.003342028118877051 ,0.040661409255705196, 0.0037246175999633598, 0.022815777468048498,0.00518907114861183, 0.018198726262235693])
mask = ArtifactVoltage_PHE != 0

plt.figure(figsize=(8, 6))
plt.errorbar(5, 0.1, 0)

plt.errorbar(tt, values, errors, fmt='s--', label=r'Artifact Voltage AHE-PHE', markersize=5, capsize=4)

plt.errorbar(t, ArtifactVoltage_AMR, ArtifactVoltage_AMR_err, fmt='o--', label=r'Artifact Voltage AHE-AMR', markersize=4, capsize=4)

plt.legend()
plt.ylabel("Normalized artifact voltage")
plt.xlabel("Pt thickness (nm)")
plt.title("Artifact voltage versus Pt thickness")
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.array([3, 5, 7, 9, 13, 15, 18])
tt = np.array([ 7, 9, 13, 18])

values = np.array([
    0.4171251296277287,
    0.1646557889946249,
    0.28404502203221105,
    0.44220046869188695
])

errors = np.array([
    0.036720069516511494,
    0.015787699855193287,
    0.01632436814400589,
    0.011129047887602278
])
ArtifactVoltage_PHE = np.array([0, 0, -0.33035330286134157, -0.045817677157164775, -0.3155801362532063,-0,-0.5460537506817336 ])
ArtifactVoltage_PHE_err = np.array([0, 0, -0.03499747447913025, -0.004362159229058996, -0.01894953739137728 ,-0.013212381797178784,-0.014091459180571872])

ArtifactVoltage_AMR = np.array([0.09042071605106773,0.15234268101028603 ,0.19926250208864596, 0.14506467824352148, 0.31643515605105343,0.3269450234471539, 0.3934388612362903])
ArtifactVoltage_AMR_err = np.array([0.007993641955864928,  0.003342028118877051 ,0.040661409255705196, 0.0037246175999633598, 0.022815777468048498,0.00518907114861183, 0.018198726262235693])
mask = ArtifactVoltage_PHE != 0

plt.figure(figsize=(6, 5))
plt.errorbar(5, 0.1, 0)
# plt.errorbar(5, 0.1, 0)

plt.errorbar(tt, values, errors, fmt='s--', label=r'Artifact Voltage AHE-PHE', markersize=5, capsize=4)

plt.errorbar(t, ArtifactVoltage_AMR, ArtifactVoltage_AMR_err, fmt='o--', label=r'Artifact Voltage AHE-AMR', markersize=4, capsize=4)

plt.legend(fontsize=12, loc='lower right')
plt.ylabel("Normalized artifact voltage", fontsize=12)
plt.xlabel("Pt thickness (nm)", fontsize=12)
# plt.title("Artifact voltage versus Pt thickness", fontsize=12)
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
t = [3, 7, 9, 13, 18]

xi_angular = [0.06593919404221206, 0.029674620606965005, 0.016227873864577236, -0.05871077753966385, -0.14293070595827487 ]
xi_angular_err = [0.00207243184407466 , 0.009025746916827011 , 0.0005730656347374585 , 0.00904134, 0.009548662263300806]
xi_first_sol = [0, 0.11580380914547889 , 0.08122173488955535, 0.08475993210801466, 0.10575315722504157]
xi_first_sol_err = [0, 0.004732995958460776 , 0.0020829645309198876, 0.0054755, 0.0036535882738209695]
xi_second_sol = [0.07366995013140397, 0.06954763615949103, 0.0530356716596044, 0.05553149108462426, 0.05806158006253529]
xi_second_sol_err = [0.0020146126064084073 , 0.0023814554118491427 , 0.0012343748462772925 , 0.00354211 , 0.0019513540094401244]



plt.figure(figsize=(8, 6))
plt.errorbar(t, xi_angular, xi_angular_err, fmt='o--', label=r'$\xi_{FMR}$ Conventional ', markersize=4, capsize=4)
plt.errorbar(t[1:], xi_first_sol[1:], xi_first_sol_err[1:], fmt='s--', label=r'$\xi_{FMR} $ AHE-PHE', markersize=4, capsize=4)
plt.errorbar(t, xi_second_sol, xi_second_sol_err, fmt= '^--', label=r'$\xi_{FMR}$ AHE-AMR', markersize=4, capsize=4)
plt.legend()
plt.ylabel("$\\xi_{FMR}$")
plt.xlabel("Pt thickness (nm)")
# plt.title("$\\xi_{FMR}$ versus Pt thickness with different methods")
plt.grid(True)

plt.show()


xi_first_sol_avg = np.mean(xi_first_sol[1:])


e = 1.602176634e-19     # elementary charge [C]
hbar = 1.055e-34
current = ((2 * e) / (hbar * xi_first_sol_avg)) * 5e-9 * 1.2 * 2.5
print(f"Current density: {current:.2e} A/m^2")
# Out:
# Current density: 4.70e+08 A/m^2

# %%
import matplotlib.pyplot as plt
import numpy as np
t = [3, 5, 7, 9, 13, 18]

xi_angular = [0.06593919404221206,0.05920069619665611, 0.029674620606965005, 0.016227873864577236, -0.05871077753966385, -0.14293070595827487 ]
xi_angular_err = [0.00207243184407466 ,0.000922317425801976 , 0.009025746916827011 , 0.0005730656347374585 , 0.00904134, 0.009548662263300806]
xi_first_sol = [0, 0, 0.11580380914547889 , 0.08122173488955535, 0.08475993210801466, 0.10575315722504157]
xi_first_sol_err = [0, 0, 0.004732995958460776 , 0.0020829645309198876, 0.0054755, 0.0036535882738209695]
xi_second_sol = [0.07366995013140397,0.08432107116996453, 0.06954763615949103, 0.0530356716596044, 0.05553149108462426, 0.05806158006253529]
xi_second_sol_err = [0.0020146126064084073 ,0.0013603871765696415 , 0.0023814554118491427 , 0.0012343748462772925 , 0.00354211 , 0.0019513540094401244]


plt.figure(figsize=(8, 6))
plt.errorbar(t, xi_angular, xi_angular_err, fmt='o--', label=r'$\xi_{FMR}$ Conventional ', markersize=4, capsize=4)
plt.errorbar(t[2:], xi_first_sol[2:], xi_first_sol_err[2:], fmt='s--', label=r'$\xi_{FMR} $ AHE-PHE', markersize=4, capsize=4)
plt.errorbar(t, xi_second_sol, xi_second_sol_err, fmt= '^--', label=r'$\xi_{FMR}$ AHE-AMR', markersize=4, capsize=4)
plt.legend()
plt.ylabel("$\\xi_{FMR}$")
plt.xlabel("Pt thickness (nm)")
plt.title("$\\xi_{FMR}$ versus Pt thickness with different methods")
plt.grid(True)

plt.show()


xi_first_sol_avg = np.mean(xi_first_sol[1:])


e = 1.602176634e-19     # elementary charge [C]
hbar = 1.055e-34
current = ((2 * e) / (hbar * xi_first_sol_avg)) * 5e-9 * 1.2 * 2.5
print(f"Current density: {current:.2e} A/m^2")
# Out:
# Current density: 5.88e+08 A/m^2

# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.array([3, 5, 7, 9, 13, 15, 18])

xi_angular = np.array([0.06593919404221206,0.05920069619665611, 0.029674620606965005, 0.016227873864577236, -0.05871077753966385, -0.060599558266368876, -0.14293070595827487 ])*1.2
xi_angular_err = np.array([0.00207243184407466 ,0.000922317425801976 , 0.009025746916827011 , 0.0005730656347374585 , 0.00904134,0.0016362164994732766 , 0.009548662263300806])*1.2
xi_first_sol = np.array([0, 0, 0.11580380914547889 , 0.08122173488955535, 0.08475993210801466,0, 0.10575315722504157])*1.2
xi_first_sol_err = np.array([0, 0, 0.004732995958460776 , 0.0020829645309198876, 0.0054755, 0, 0.0036535882738209695])*1.2
xi_second_sol = np.array([0.07366995013140397,0.08432107116996453, 0.06954763615949103, 0.0530356716596044, 0.05553149108462426,0.07502855929625217 , 0.05806158006253529])*1.2
xi_second_sol_err = np.array([0.0020146126064084073 ,0.0013603871765696415 , 0.0023814554118491427 , 0.0012343748462772925 , 0.00354211 , 0.0022254977519742623, 0.0019513540094401244])*1.2

mask = xi_first_sol != 0
plt.figure(figsize=(6, 5))
plt.errorbar(t, xi_angular, xi_angular_err, fmt='o--', label=r'$\xi_{FMR}$ Conventional ', markersize=4, capsize=4)
plt.errorbar(t[mask], xi_first_sol[mask], xi_first_sol_err[mask], fmt='s--', label=r'$\xi_{FMR} $ AHE-PHE', markersize=4, capsize=4)
plt.errorbar(t, xi_second_sol, xi_second_sol_err, fmt= '^--', label=r'$\xi_{FMR}$ AHE-AMR', markersize=4, capsize=4)
plt.legend(fontsize=12)
plt.ylabel("$\\xi_{FMR}$", fontsize=12)
plt.xlabel("Pt thickness (nm)", fontsize=12)
# plt.title("$\\xi_{FMR}$ versus Pt thickness with different methods")
plt.grid(True)

plt.show()


xi_first_sol_avg = np.mean(xi_first_sol[1:])


e = 1.602176634e-19     # elementary charge [C]
hbar = 1.055e-34
current = ((2 * e) / (hbar * xi_first_sol_avg)) * 5e-9 * 1.2 * 2.5
print(f"Current density: {current:.2e} A/m^2")
# Out:
# Current density: 5.88e+08 A/m^2
