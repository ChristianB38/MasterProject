# %%
# SSN124: power 0
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN124 = r".\\SSN101\\FrequencyScan"
stfmr = STFMR(folder=Folder_SSN124, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=8e-9, d_NM=15e-9, Width=20e-6, Length=20e-6, sample_name='Pt(5)/CoFeB(4)')

# stfmr.analyze_traces(plot=True)
# stfmr.average_fitparams(plot=True)
# stfmr.plot_averages()
# stfmr.plot_quick_scans()
# stfmr.plot_Kittel(plot=True)
# stfmr.plot_linewidth(plot=True)
stfmr.calculate_xiFMR(plot=True)
# Out:
# Vs/Va 0.36970379969830586 Vs -13.356525508675237 Va -36.12763926033418 Hres 0.09987904272484828 Meff 1.13379896956807 Ms 1000000.0 d_FM 8e-09 d_NM 1.5e-08
# C 0.22900715115651746 Sqrt term 3.514501447914414 eta 0.36970379969830586 xi_FMR 0.29755461118181464
# Vs/Va 0.3881272094673262 Vs -26.790739351829483 Va -69.02566658131917 Hres 0.10851709305253132 Meff 1.13379896956807 Ms 1000000.0 d_FM 8e-09 d_NM 1.5e-08
# C 0.22900715115651746 Sqrt term 3.3835061838126426 eta 0.3881272094673262 xi_FMR 0.300739247373639
# Vs/Va 0.3986149105359779 Vs -11.113634300724668 Va -27.880628664344908 Hres 0.11925036650953236 Meff 1.13379896956807 Ms 1000000.0 d_FM 8e-09 d_NM 1.5e-08
# C 0.22900715115651746 Sqrt term 3.2415611903726793 eta 0.3986149105359779 xi_FMR 0.29590806912941964
# Vs/Va 0.4085468847316496 Vs -20.82830709578372 Va -50.98143658460304 Hres 0.12854010706827984 Meff 1.13379896956807 Ms 1000000.0 d_FM 8e-09 d_NM 1.5e-08
# ...

# %%
# SSN095: power 0
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN095 = r".\\SSN095\\FrequencyScan"
stfmr = STFMR(folder=Folder_SSN095, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=2e-9, d_NM=5e-9, Width=20e-6, Length=20e-6)

# stfmr.plot_traces()
# stfmr.average_fitparams(plot=True)
stfmr.plot_averages()
stfmr.plot_quick_scans()

stfmr.plot_Kittel(plot=True)
stfmr.plot_Kittel2(plot=True)
stfmr.plot_linewidth(plot=True)
# stfmr.calculate_xiFMR(plot=True)
# Out:
# ⚠️ Skipping Averaged_Traces_posB: no proper file.
# ⚠️ Skipping fit_results_average_posB.csv: no proper file.
# Hk= 0.9807903443211108 Meff= 7.86722991193667e-22
#                                             Filename   phi  freq  pow_ trace  \
# 3  FrequencyScan_Phi_45.00deg_Freq_9.00GHz_Pow_5....  45.0   9.0   5.0   avg
# 0  FrequencyScan_Phi_45.00deg_Freq_10.00GHz_Pow_5...  45.0  10.0   5.0   avg
# 1  FrequencyScan_Phi_45.00deg_Freq_11.00GHz_Pow_5...  45.0  11.0   5.0   avg
# 2  FrequencyScan_Phi_45.00deg_Freq_12.00GHz_Pow_5...  45.0  12.0   5.0   avg
#
#          Vs     Vsstd         Va     Vastd        Hres   Hresstd     Delta  \
# 3  4.631697  0.007687 -26.006624  0.089269   94.237660  0.033576  4.532856
# 0  4.338458  0.047755 -20.468037  0.009158  113.417910  0.049270  4.588614
# 1  3.197074  0.039081 -15.413301  0.075103  133.853421  0.044579  4.410744
# 2  3.271242  0.012860 -14.760485  0.069236  156.465692  0.035958  4.680021
#
#    Deltastd         C      Cstd   D  Dstd
# ...

# %%
# SSN101: power 0
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN101 = r".\\SSN101\\FrequencyScan"
stfmr = STFMR(folder=Folder_SSN101, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=2e-9, d_NM=5e-9, Width=20e-6, Length=20e-6)

# stfmr.plot_traces()
# stfmr.average_fitparams(plot=True)
stfmr.plot_averages()
# stfmr.plot_quick_scans()
stfmr.plot_Kittel(plot=True)
# stfmr.plot_linewidth(plot=True)
stfmr.calculate_xiFMR(plot=True)

# %%
# SSN145: power 0
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN145 = r".\\SSN145\\FrequencyScan"
stfmr = STFMR(folder=Folder_SSN145, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=4e-9, d_NM=0e-9, Width=20e-6, Length=40e-6)

# stfmr.plot_traces()
# stfmr.average_fitparams(plot=True)
# stfmr.plot_averages()
# stfmr.plot_quick_scans()

# stfmr.plot_Kittel(plot=True)
# stfmr.plot_Kittel2(plot=True)
# stfmr.plot_linewidth(plot=True)
stfmr.calculate_xiFMR(plot=True)

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

thickness_map = {
    # "SSN092": {"t_FM": 2e-9,"t_NM": 15e-9,"label": "15nm"},
    # "SSN093": {"t_FM": 2.5e-9,"t_NM": 15e-9,"label": "15nm"},
    # "SSN094": {"t_FM": 3e-9,"t_NM": 15e-9,"label": "15nm"},
    # "SSN095": {"t_FM": 4e-9,"t_NM": 15e-9,"label": "15nm"},
    # "DK159": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm"},
    # "SSN096": {"t_FM": 8e-9,"t_NM": 15e-9,"label": "15nm"},
    # "SSN097": {"t_FM": 10e-9,"t_NM": 15e-9,"label": "15nm"},

    "SSN098": {"t_FM": 2e-9,"t_NM": 5e-9,"label": "5nm"},
    "SSN099": {"t_FM": 2.5e-9,"t_NM": 5e-9,"label": "5nm"},
    "SSN100": { "t_FM": 3e-9,"t_NM": 5e-9,"label": "5nm"},
    "SSN101": {"t_FM": 4e-9,"t_NM": 5e-9,"label": "5nm"},
    "DK158": {"t_FM": 5e-9,"t_NM": 5e-9,"label": "5nm"},
    "SSN102": {"t_FM": 8e-9,"t_NM": 5e-9,"label": "5nm"},
    "SSN103": {"t_FM": 10e-9,"t_NM": 5e-9,"label": "5nm"},

    # "SSN121": {"t_FM": 2e-9,"t_NM": 15e-9,"label": "Mgo"},
    # "SSN122": {"t_FM": 2.5e-9,"t_NM": 15e-9,"label": "Mgo"},
    # "SSN123": {"t_FM": 3e-9,"t_NM": 15e-9,"label": "Mgo"},
    # "SSN124": {"t_FM": 4e-9,"t_NM": 15e-9,"label": "Mgo"},
    # "DK161": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "Mgo"},
    # "SSN125": {"t_FM": 8e-9,"t_NM": 15e-9,"label": "Mgo"},
    # "SSN126": {"t_FM": 10e-9,"t_NM": 15e-9,"label": "Mgo"},
    
    # "SSN145": {"t_FM": 4e-9,"t_NM": 0e-9,"label": "CFB"}
}


voltage_unit='uV'
used_fields='Pos'
Ms=1.2e6
d_NM=15e-9
Width=20e-6
Length=20e-6

STFMR_ = STFMR_thickness_analysis(folder = r".", voltage_unit=voltage_unit, d_FMs=thickness_map, d_NM=d_NM, Ms=Ms, Width=Width, Length=Length, group_name='Pt(5)/CoFeB($t_{{FM}}$) heterostructures')

STFMR_.analyze_thickness_folder()
# STFMR_.plot_average_frequency(freq=11)

STFMR_.plot_different_groups(title="$\\xi_{FMR}$ versus $t_{FM}$ for Pt(5)/CoFeB($t_{FM}$) heterostructures")
# STFMR_.subtract_mgo_background()

# STFMR_.plot_linewidths()
# STFMR_.plot_alpha()
# STFMR_.plot_DeltaH0()

# STFMR_.plot_kittels()
STFMR_.plot_Meff()

# STFMR_.plot_xi()
STFMR_.plot_xi_inv() #changes self.results
# Out:
# ⚠️ Skipping AllGroups.ipynb: no FrequencyScan folder.
# 🔍 Analyzing DK158 (t_FM= 5e-09 nm)
# ⚠️ Thickness for DK159 not found.
# ⚠️ Thickness for DK161 not found.
# ⚠️ Thickness for SSN092 not found.
# ⚠️ Thickness for SSN093 not found.
# ⚠️ Thickness for SSN094 not found.
# ⚠️ Thickness for SSN095 not found.
# ⚠️ Thickness for SSN096 not found.
# ⚠️ Thickness for SSN097 not found.
# 🔍 Analyzing SSN098 (t_FM= 2e-09 nm)
# 🔍 Analyzing SSN099 (t_FM= 2.5e-09 nm)
# 🔍 Analyzing SSN100 (t_FM= 3e-09 nm)
# 🔍 Analyzing SSN101 (t_FM= 4e-09 nm)
# 🔍 Analyzing SSN102 (t_FM= 8e-09 nm)
# 🔍 Analyzing SSN103 (t_FM= 1e-08 nm)
# ⚠️ Thickness for SSN121 not found.
# ⚠️ Thickness for SSN122 not found.
# ⚠️ Thickness for SSN123 not found.
# ⚠️ Thickness for SSN124 not found.
# ⚠️ Thickness for SSN125 not found.
# ⚠️ Thickness for SSN126 not found.
# ⚠️ Thickness for SSN145 not found.
#    Sample          t_FM          t_NM Label    Xi_fmr  Xi_fmr_std      Meff  \
# ...

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

thickness_map = {
    "SSN092": {"t_FM": 2e-9,"t_NM": 15e-9,"label": "15nm"},
    "SSN093": {"t_FM": 2.5e-9,"t_NM": 15e-9,"label": "15nm"},
    "SSN094": {"t_FM": 3e-9,"t_NM": 15e-9,"label": "15nm"},
    "SSN095": {"t_FM": 4e-9,"t_NM": 15e-9,"label": "15nm"},
    "DK159": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm"},
    "SSN096": {"t_FM": 8e-9,"t_NM": 15e-9,"label": "15nm"},
    "SSN097": {"t_FM": 10e-9,"t_NM": 15e-9,"label": "15nm"},


    "SSN121": {"t_FM": 2e-9,"t_NM": 15e-9,"label": "Mgo"},
    "SSN122": {"t_FM": 2.5e-9,"t_NM": 15e-9,"label": "Mgo"},
    "SSN123": {"t_FM": 3e-9,"t_NM": 15e-9,"label": "Mgo"},
    "SSN124": {"t_FM": 4e-9,"t_NM": 15e-9,"label": "Mgo"},
    "DK161": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "Mgo"},
    "SSN125": {"t_FM": 8e-9,"t_NM": 15e-9,"label": "Mgo"},
    "SSN126": {"t_FM": 10e-9,"t_NM": 15e-9,"label": "Mgo"},
}


voltage_unit='uV'
used_fields='Pos'
Ms=1.2e6
d_NM=15e-9
Width=20e-6
Length=20e-6

STFMR_ = STFMR_thickness_analysis(folder = r".", voltage_unit=voltage_unit, d_FMs=thickness_map, d_NM=d_NM, Ms=Ms, Width=Width, Length=Length)

# STFMR_.analyze_thickness_folder()
# STFMR_.plot_average_frequency(freq=11)

STFMR_.subtract_Mgo_background_old()
# STFMR_.plot_linewidths()
# STFMR_.plot_alpha()
# STFMR_.plot_DeltaH0()

# STFMR_.plot_kittels()
STFMR_.plot_Meff()

STFMR_.plot_xi()
# STFMR_.plot_xi_inv(fit=False) #changes self.results
# Out:
# [OK] Averaged data exists for SSN092
# [OK] Averaged data exists for SSN093
# [OK] Averaged data exists for SSN094
# [OK] Averaged data exists for SSN095
# [OK] Averaged data exists for DK159
# [OK] Averaged data exists for SSN096
# [OK] Averaged data exists for SSN097
# [OK] Averaged data exists for SSN121
# [OK] Averaged data exists for SSN122
# [OK] Averaged data exists for SSN123
# [OK] Averaged data exists for SSN124
# [OK] Averaged data exists for DK161
# [OK] Averaged data exists for SSN125
# [OK] Averaged data exists for SSN126
# [WARN] Missing MgO file: Average_Phi_45.00deg_Freq_10.00GHz_Pow_0.00dBm_Curr_0mA_Trace_0.txt
# [WARN] Missing MgO file: Average_Phi_45.00deg_Freq_11.00GHz_Pow_0.00dBm_Curr_0mA_Trace_0.txt
# [WARN] Missing MgO file: Average_Phi_45.00deg_Freq_12.00GHz_Pow_0.00dBm_Curr_0mA_Trace_0.txt
# [WARN] Missing MgO file: Average_Phi_45.00deg_Freq_8.00GHz_Pow_0.00dBm_Curr_0mA_Trace_0.txt
# ...
