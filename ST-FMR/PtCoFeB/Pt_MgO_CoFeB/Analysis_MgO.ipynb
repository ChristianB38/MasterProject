# %%
# Sample SSN121: FCB2/MgO2/Pt15
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module

importlib.reload(analysis_module)

from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN121 = r".\\SSN121\\FrequencyScan"

stfmr = STFMR(folder=Folder_SSN121, voltage_unit='uV', used_fields='Pos', Ms=1e3, d_FM=2e-9, d_NM=5e-9, Width=20e-6, Length=20e-6)


stfmr.average_fitparams(plot=False)
stfmr.plot_Kittel(plot=True)
stfmr.plot_linewidth(plot=True)
# Out:
#                                             Filename   phi  freq  pow_ trace  \
# 3  FrequencyScan_Phi_45.00deg_Freq_8.00GHz_Pow_5....  45.0   8.0   5.0   avg
# 4  FrequencyScan_Phi_45.00deg_Freq_9.00GHz_Pow_5....  45.0   9.0   5.0   avg
# 0  FrequencyScan_Phi_45.00deg_Freq_10.00GHz_Pow_5...  45.0  10.0   5.0   avg
# 1  FrequencyScan_Phi_45.00deg_Freq_11.00GHz_Pow_5...  45.0  11.0   5.0   avg
# 2  FrequencyScan_Phi_45.00deg_Freq_12.00GHz_Pow_5...  45.0  12.0   5.0   avg
#
#          Vs     Vsstd        Va     Vastd        Hres   Hresstd     Delta  \
# 3  0.232378  0.005505 -2.052390  0.010638  127.733714  0.102789  5.638537
# 4  0.276278  0.000038 -2.165687  0.011841  156.345618  0.053125  6.354582
# 0  0.208317  0.009297 -1.714815  0.020538  185.690967  0.140642  6.221803
# 1  0.144380  0.000111 -1.252111  0.000191  216.174988  0.064795  6.157416
# 2  0.138783  0.004411 -1.182887  0.019554  248.306727  0.048874  6.507114
#
#    Deltastd         C      Cstd
# ...

# %%
# Sample SSN122
import importlib
import Analysis
importlib.reload(Analysis)

Folder_SSN122 = r".\\SSN122\\FrequencyScan"
stfmr = Analysis.STFMR(folder=Folder_SSN122, voltage_unit='uV', used_fields='Pos', Ms=1e3, d_FM=2.5e-9, d_NM=5e-9, Width=20e-6, Length=20e-6)

stfmr.average_fitparams(plot=False)
stfmr.plot_Kittel(plot=True)
stfmr.plot_linewidth(plot=True)
# Out:
#                                             Filename   phi  freq  pow_ trace  \
# 3  FrequencyScan_Phi_45.00deg_Freq_8.00GHz_Pow_5....  45.0   8.0   5.0   avg
# 4  FrequencyScan_Phi_45.00deg_Freq_9.00GHz_Pow_5....  45.0   9.0   5.0   avg
# 0  FrequencyScan_Phi_45.00deg_Freq_10.00GHz_Pow_5...  45.0  10.0   5.0   avg
# 1  FrequencyScan_Phi_45.00deg_Freq_11.00GHz_Pow_5...  45.0  11.0   5.0   avg
# 2  FrequencyScan_Phi_45.00deg_Freq_12.00GHz_Pow_5...  45.0  12.0   5.0   avg
#
#          Vs     Vsstd        Va     Vastd        Hres   Hresstd     Delta  \
# 3  1.002566  0.011453 -7.059458  0.038603  104.610258  0.019689  4.779864
# 4  1.225773  0.022114 -7.759358  0.027173  129.168517  0.047437  5.463770
# 0  1.049478  0.001321 -6.223714  0.037438  154.493497  0.051421  5.358776
# 1  0.816167  0.013068 -4.661329  0.013929  180.993554  0.080793  5.088896
# 2  0.842979  0.002480 -4.458418  0.022365  209.460130  0.095130  5.366572
#
#    Deltastd         C      Cstd
# ...

# %%
# Sample SSN123 Pt(15)/Mgo2/CoFeB(3)
import importlib
import Analysis
importlib.reload(Analysis)

Folder_SSN123 = r".\\SSN123\\FrequencyScan"
stfmr = Analysis.STFMR(folder=Folder_SSN123, voltage_unit='uV', used_fields='Pos', Ms=1e3, d_FM=3e-9, d_NM=5e-9, Width=20e-6, Length=20e-6)

stfmr.average_fitparams(plot=False)
stfmr.plot_Kittel(plot=True)
stfmr.plot_linewidth(plot=True)
# Out:
#                                             Filename   phi  freq  pow_ trace  \
# 3  FrequencyScan_Phi_45.00deg_Freq_8.00GHz_Pow_5....  45.0   8.0   5.0   avg
# 4  FrequencyScan_Phi_45.00deg_Freq_9.00GHz_Pow_5....  45.0   9.0   5.0   avg
# 0  FrequencyScan_Phi_45.00deg_Freq_10.00GHz_Pow_5...  45.0  10.0   5.0   avg
# 1  FrequencyScan_Phi_45.00deg_Freq_11.00GHz_Pow_5...  45.0  11.0   5.0   avg
# 2  FrequencyScan_Phi_45.00deg_Freq_12.00GHz_Pow_5...  45.0  12.0   5.0   avg
#
#          Vs     Vsstd         Va     Vastd        Hres   Hresstd     Delta  \
# 3  2.447563  0.031646 -14.228282  0.076470   88.919715  0.000962  4.660101
# 4  3.099230  0.003143 -15.634641  0.076181  110.589983  0.019049  5.239638
# 0  2.745490  0.003073 -12.546573  0.042973  132.831720  0.044936  5.163993
# 1  2.188711  0.014128  -9.411063  0.043196  156.460167  0.007445  4.996218
# 2  2.230760  0.025109  -9.099250  0.046130  182.140485  0.021912  5.245065
#
#    Deltastd         C      Cstd
# ...

# %%
# Sample SSN124 FCB(4)/Pt(5)
import importlib
import Analysis
importlib.reload(Analysis)

Folder_SSN124 = r".\\SSN124\\FrequencyScan"
stfmr = Analysis.STFMR(folder=Folder_SSN124, voltage_unit='uV', used_fields='Pos', Ms=1e3, d_FM=4e-9, d_NM=5e-9, Width=20e-6, Length=20e-6)

stfmr.average_fitparams(plot=False)
stfmr.plot_Kittel(plot=True)
stfmr.plot_linewidth(plot=True)
# Out:
#                                             Filename   phi  freq  pow_ trace  \
# 3  FrequencyScan_Phi_45.00deg_Freq_8.00GHz_Pow_5....  45.0   8.0   5.0   avg
# 4  FrequencyScan_Phi_45.00deg_Freq_9.00GHz_Pow_5....  45.0   9.0   5.0   avg
# 0  FrequencyScan_Phi_45.00deg_Freq_10.00GHz_Pow_5...  45.0  10.0   5.0   avg
# 1  FrequencyScan_Phi_45.00deg_Freq_11.00GHz_Pow_5...  45.0  11.0   5.0   avg
# 2  FrequencyScan_Phi_45.00deg_Freq_12.00GHz_Pow_5...  45.0  12.0   5.0   avg
#
#          Vs     Vsstd         Va     Vastd        Hres   Hresstd     Delta  \
# 3  3.672166  0.045460 -23.994586  0.019875   75.385392  0.025157  3.946956
# 4  4.916219  0.009513 -25.955771  0.088917   94.178831  0.032919  4.604089
# 0  4.396693  0.041588 -20.454178  0.009447  113.403109  0.047626  4.606000
# 1  3.231277  0.036318 -15.395323  0.075312  133.844357  0.043597  4.396734
# 2  3.350768  0.010654 -14.719889  0.070707  156.443272  0.034806  4.639215
#
#    Deltastd         C      Cstd
# ...

# %%
# Sample SSN161 FCB(5)
import importlib
import Analysis
importlib.reload(Analysis)

Folder_SSN161 = r".\\DK161\\FrequencyScan"
stfmr = Analysis.STFMR(folder=Folder_SSN161, voltage_unit='uV', used_fields='Pos', Ms=1e3, d_FM=8e-9, d_NM=5e-9, Width=20e-6, Length=20e-6)

stfmr.average_fitparams(plot=False)
stfmr.plot_Kittel(plot=True)
stfmr.plot_linewidth(plot=True)
# Out:
# Deleted existing results file at .\\DK161\\FrequencyScan\fit_results_average_posB.csv to create a new one.
#                                             Filename   phi  freq  pow_ trace  \
# 5  FrenquencyScan_Phi_45.00deg_Freq_8.00GHz_Pow_5...  45.0   8.0   5.0   avg
# 6  FrenquencyScan_Phi_45.00deg_Freq_9.00GHz_Pow_5...  45.0   9.0   5.0   avg
# 0  FrenquencyScan_Phi_45.00deg_Freq_10.00GHz_Pow_...  45.0  10.0   5.0   avg
# 1  FrenquencyScan_Phi_45.00deg_Freq_11.00GHz_Pow_...  45.0  11.0   5.0   avg
# 2  FrenquencyScan_Phi_45.00deg_Freq_12.00GHz_Pow_...  45.0  12.0   5.0   avg
# 3  FrenquencyScan_Phi_45.00deg_Freq_13.00GHz_Pow_...  45.0  13.0   5.0   avg
# 4  FrenquencyScan_Phi_45.00deg_Freq_14.00GHz_Pow_...  45.0  14.0   5.0   avg
#
#          Vs     Vsstd         Va     Vastd        Hres   Hresstd     Delta  \
# 5  2.028114  0.026103 -18.738157  0.173315   67.818757  0.021766  3.395788
# 6  3.608943  0.074237 -21.974036  0.088587   85.384502  0.049607  4.181489
# ...

# %%
# Sample SSN125
import importlib
import Analysis
importlib.reload(Analysis)

Folder_SSN125 = r".\\SSN125\\FrequencyScan"
stfmr = Analysis.STFMR(folder=Folder_SSN125, voltage_unit='uV', used_fields='Pos', Ms=1e3, d_FM=8e-9, d_NM=5e-9, Width=20e-6, Length=20e-6)

# stfmr.plot_traces()
stfmr.average_fitparams(plot=False)
stfmr.plot_Kittel(plot=True)
stfmr.plot_linewidth(plot=True)
# Out:
#                                             Filename   phi  freq  pow_ trace  \
# 3  FrequencyScan_Phi_45.00deg_Freq_8.00GHz_Pow_0....  45.0   8.0   0.0   avg
# 4  FrequencyScan_Phi_45.00deg_Freq_9.00GHz_Pow_0....  45.0   9.0   0.0   avg
# 0  FrequencyScan_Phi_45.00deg_Freq_10.00GHz_Pow_0...  45.0  10.0   0.0   avg
# 1  FrequencyScan_Phi_45.00deg_Freq_11.00GHz_Pow_0...  45.0  11.0   0.0   avg
# 2  FrequencyScan_Phi_45.00deg_Freq_12.00GHz_Pow_0...  45.0  12.0   0.0   avg
#
#          Vs     Vsstd         Va     Vastd        Hres   Hresstd     Delta  \
# 3 -2.957030  0.010803 -22.981456  0.107696   60.174143  0.007313  2.994792
# 4 -2.339779  0.017259 -26.115747  0.108204   75.434720  0.015878  3.198350
# 0 -1.309575  0.026170 -19.338634  0.038590   91.944720  0.043926  3.118351
# 1 -0.120361  0.000848 -14.484882  0.014581  110.368231  0.014765  2.905655
# 2  0.483638  0.017186 -15.095958  0.035814  130.005778  0.022828  3.118291
#
#    Deltastd         C      Cstd
# ...

# %%
# Sample SSN126
import importlib
import Analysis
importlib.reload(Analysis)

Folder_SSN126 = r".\\SSN126\\FrequencyScan"
stfmr = Analysis.STFMR(folder=Folder_SSN126, voltage_unit='uV', used_fields='Pos', Ms=1e3, d_FM=10e-9, d_NM=5e-9, Width=20e-6, Length=20e-6)

# stfmr.plot_traces()
stfmr.average_fitparams(plot=False)
stfmr.plot_Kittel(plot=True)
stfmr.plot_linewidth(plot=True)
# Out:
# Deleted existing results file at .\\SSN126\\FrequencyScan\fit_results_average_posB.csv to create a new one.
#                                             Filename   phi  freq  pow_ trace  \
# 3  FrequencyScan_Phi_45.00deg_Freq_8.00GHz_Pow_0....  45.0   8.0   0.0   avg
# 4  FrequencyScan_Phi_45.00deg_Freq_9.00GHz_Pow_0....  45.0   9.0   0.0   avg
# 0  FrequencyScan_Phi_45.00deg_Freq_10.00GHz_Pow_0...  45.0  10.0   0.0   avg
# 1  FrequencyScan_Phi_45.00deg_Freq_11.00GHz_Pow_0...  45.0  11.0   0.0   avg
# 2  FrequencyScan_Phi_45.00deg_Freq_12.00GHz_Pow_0...  45.0  12.0   0.0   avg
#
#          Vs     Vsstd         Va     Vastd        Hres   Hresstd     Delta  \
# 3 -5.167779  0.048251 -25.644966  0.114840   56.442237  0.002032  3.229102
# 4 -4.528756  0.034130 -29.976028  0.123914   71.211390  0.037188  3.381195
# 0 -3.525800  0.011555 -22.498784  0.038515   87.270887  0.001917  3.213628
# 1 -1.817734  0.019717 -16.039982  0.007871  105.425074  0.006793  3.171778
# ...

# %%
# Sample SSN097 FCB(10)/Pt(15)
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

thickness_map = {
    "DK161": 5*1e-9,    # nm
    "SSN121": 2*1e-9,
    "SSN122": 2.5*1e-9,
    "SSN123": 3*1e-9,
    "SSN124": 4*1e-9,
    "SSN125": 8*1e-9,
    "SSN126": 10*1e-9,
}


voltage_unit='uV'
used_fields='Pos'
Ms=1.2e6
d_NM=15e-9
Width=20e-6
Length=20e-6

STFMR_ = STFMR_thickness_analysis(folder = r".", voltage_unit=voltage_unit, d_FMs=thickness_map, d_NM=d_NM, Ms=Ms, Width=Width, Length=Length, group_name='Pt(15)/MgO(2)/CoFeB(t) samples')

STFMR_.analyze_thickness_folder()
STFMR_.plot_xi()
STFMR_.plot_frequency(freq=8)

STFMR_.plot_linewidths()
# STFMR_.plot_alpha()
# STFMR_.plot_DeltaH0()

STFMR_.plot_kittels()
STFMR_.plot_Meff()

STFMR_.plot_xi_inv() # !!! canchange self.results by removing certain samples
# Out:
# ⚠️ Skipping Analysis_MgO.ipynb: no FrequencyScan folder.
# 🔍 Analyzing DK161 (t_FM= 5e-09 nm)
# 🔍 Analyzing SSN121 (t_FM= 2e-09 nm)
# 🔍 Analyzing SSN122 (t_FM= 2.5e-09 nm)
# 🔍 Analyzing SSN123 (t_FM= 3.0000000000000004e-09 nm)
# 🔍 Analyzing SSN124 (t_FM= 4e-09 nm)
# 🔍 Analyzing SSN125 (t_FM= 8e-09 nm)
# 🔍 Analyzing SSN126 (t_FM= 1e-08 nm)
# 🔍 Analyzing SSN121 (t_FM= 2e-09 nm)
# 🔍 Analyzing SSN122 (t_FM= 2.5e-09 nm)
# 🔍 Analyzing SSN123 (t_FM= 3.0000000000000004e-09 nm)
# 🔍 Analyzing SSN124 (t_FM= 4e-09 nm)
# 🔍 Analyzing DK161 (t_FM= 5e-09 nm)
# 🔍 Analyzing SSN125 (t_FM= 8e-09 nm)
# 🔍 Analyzing SSN126 (t_FM= 1e-08 nm)
# 🔍 Analyzing SSN121 (t_FM= 2e-09 nm)
# 🔍 Analyzing SSN122 (t_FM= 2.5e-09 nm)
# 🔍 Analyzing SSN123 (t_FM= 3.0000000000000004e-09 nm)
# 🔍 Analyzing SSN124 (t_FM= 4e-09 nm)
# 🔍 Analyzing DK161 (t_FM= 5e-09 nm)
# 🔍 Analyzing SSN125 (t_FM= 8e-09 nm)
# 🔍 Analyzing SSN126 (t_FM= 1e-08 nm)
# 🔍 Analyzing SSN121 (t_FM= 2e-09 nm)
# 🔍 Analyzing SSN122 (t_FM= 2.5e-09 nm)
# ...
