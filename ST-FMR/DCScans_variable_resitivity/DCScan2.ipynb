# %% [markdown]
# | Sample | Pt thickness (nm) | Pt resistivity (µΩ·cm) | CoFeB resistivity (µΩ·cm) |
# | ------ | ----------------: | ---------------------: | ------------------------: |
# | SSN138 |                 3 |                     63 |                       170 |
# | SSN101 |                 5 |                     45 |                       170 |
# | SSN139 |                 7 |                     37 |                       170 |
# | SSN141 |                 9 |                     33 |                       170 |
# | SSN142 |                13 |                     29 |                       170 |
# | SSN143 |                13 |                     29 |                       170 |
# | SSN095 |                15 |                     28 |                       170 |
# | SSN140 |                18 |                     27 |                       170 |

# %%
# Sample SSN095 FCB(4)/Pt(15)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN095 = r".\\SSN095" 
stfmr = STFMR(folder=Folder_SSN095, voltage_unit='uV', used_fields='Neg', Ms=1.2e6, d_FM=4e-9, d_NM=15e-9, Width=20e-6, Length=40e-6)

# stfmr.average_fitparams(plot=True)


# stfmr.analyze_traces(plot=True)
# stfmr.average_fitparams(plot=True)

stfmr.DCScan(method="Average_fitparams", Meff=1.17, Meff_err=0.0030005526372648603, resistivity_Pt=28e8, resistivity_CFB=170e8)
# stfmr.calculate_xiFMR(plot=True)
# Out:
# Intersection J_Pt x: 5.900598753562699
# Intersection J_Pt error: 0.3917050282535285
# Intersection alpha y: 0.020172381638009194
# Intersection alpha error: 1.785664605932739e-05
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# Using variables: mu0 = 1.2566370614359173e-06 T·m/A, Ms = 1200000.0 A/m, t_FM = 4e-09 m, theta = 45.0 degrees, f = 10000000000.0 Hz, mu0 Meff = 1.12 T, Hext = 0.09998852339972593 T, slope = 1.0512999594425837e-15 mT/mA (T/A)
# Slope = (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * theta_sh
# theta_sh = ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t) / sin(theta) * (gamma / 2*pi*f) * Slope * (2 e /  hbar)
# ...

# %%
# Sample SSN101 FCB(4)/Pt(5)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN101 = r".\\SSN101\\transverse_DCbias_25012026" 
stfmr = STFMR(folder=Folder_SSN101, voltage_unit='uV', used_fields='Neg', Ms=1.2e6, d_FM=4e-9, d_NM=5e-9, Width=20e-6, Length=40e-6)

# stfmr.average_fitparams(plot=True)


# stfmr.analyze_traces(plot=True)
# stfmr.average_fitparams(plot=True)
stfmr.DCScan(method="Average_fitparams", Meff=1.122805, Meff_err=0.002471033565695086, resistivity_Pt=45e8, resistivity_CFB=170e8)
# stfmr.calculate_xiFMR(plot=True)
# Out:
# Intersection J_Pt x: 0.9882593952725348
# Intersection J_Pt error: 0.09255863769295596
# Intersection alpha y: 0.01757722904741364
# Intersection alpha error: 5.9489757997665726e-06
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# Using variables: mu0 = 1.2566370614359173e-06 T·m/A, Ms = 1200000.0 A/m, t_FM = 4e-09 m, theta = 45.0 degrees, f = 10000000000.0 Hz, mu0 Meff = 1.12 T, Hext = 0.10328141252929732 T, slope = 1.7214326586790439e-15 mT/mA (T/A)
# Slope = (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * theta_sh
# theta_sh = ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t) / sin(theta) * (gamma / 2*pi*f) * Slope * (2 e /  hbar)
# ...

# %%
# Sample SSN138 FCB(4)/Pt(3) trans
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN138 = r".\\SSN138\\DCScan_transverse"
stfmr = STFMR(folder=Folder_SSN138, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=3e-9, Width=20e-6, Length=60e-6)

# stfmr.analyze_traces(plot=True)
stfmr.DCScan(method="Average_fitparams", Meff= 1.193529, Meff_err=0.0050972348761976725, resistivity_Pt=63e8, resistivity_CFB=170e8)
# stfmr.calculate_xiFMR(plot=True)
# Out:
# Intersection J_Pt x: 2.4032522209231866
# Intersection J_Pt error: 0.10522879578620238
# Intersection alpha y: 0.016681530069362214
# Intersection alpha error: 9.746136155719215e-06
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# Using variables: mu0 = 1.2566370614359173e-06 T·m/A, Ms = 1200000.0 A/m, t_FM = 4e-09 m, theta = 45.0 degrees, f = 10000000000.0 Hz, mu0 Meff = 1.12 T, Hext = 0.09461942956786751 T, slope = 2.2700921626014268e-15 mT/mA (T/A)
# Slope = (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * theta_sh
# theta_sh = ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t) / sin(theta) * (gamma / 2*pi*f) * Slope * (2 e /  hbar)
# ...

# %%
# Sample SSN141 FCB(4)/Pt(9) trans
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN141 = r".\\SSN141\\DCScan_Transverse"
stfmr = STFMR(folder=Folder_SSN141, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=9e-9, Width=20e-6, Length=60e-6)


# stfmr.analyze_traces(plot=True)
stfmr.DCScan(method="Average_fitparams", Meff= 1.172705, Meff_err=0.0022004057188310198, resistivity_Pt=33e8, resistivity_CFB=170e8)
# stfmr.calculate_xiFMR(plot=True)
# Out:
# Intersection J_Pt x: 1.583677305084754
# Intersection J_Pt error: 0.27385117835192513
# Intersection alpha y: 0.01909468732115135
# Intersection alpha error: 2.1727544455605028e-05
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# Using variables: mu0 = 1.2566370614359173e-06 T·m/A, Ms = 1200000.0 A/m, t_FM = 4e-09 m, theta = 45.0 degrees, f = 10000000000.0 Hz, mu0 Meff = 1.12 T, Hext = 0.10086996049856907 T, slope = 9.47793372607834e-16 mT/mA (T/A)
# Slope = (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * theta_sh
# theta_sh = ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t) / sin(theta) * (gamma / 2*pi*f) * Slope * (2 e /  hbar)
# ...

# %%
# Sample SSN143 FCB(4)/Pt(13) trans
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN143 = r".\\SSN143\\DCscan_long_xx"
stfmr = STFMR(folder=Folder_SSN143, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=13e-9, Width=20e-6, Length=60e-6)


# stfmr.analyze_traces(plot=True)
stfmr.DCScan(method="Average_fitparams", Meff=1.176010, Meff_err=0.0015341870252315744, resistivity_Pt=29e8, resistivity_CFB=170e8)
# stfmr.calculate_xiFMR(plot=True)
# Out:
# Intersection J_Pt x: 5.9770588503445525
# Intersection J_Pt error: 0.3818321115090066
# Intersection alpha y: 0.017726531038459725
# Intersection alpha error: 3.239425887481396e-05
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# Using variables: mu0 = 1.2566370614359173e-06 T·m/A, Ms = 1200000.0 A/m, t_FM = 4e-09 m, theta = 45.0 degrees, f = 10000000000.0 Hz, mu0 Meff = 1.12 T, Hext = 0.10032828187719707 T, slope = 1.3281453915622634e-15 mT/mA (T/A)
# Slope = (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * theta_sh
# theta_sh = ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t) / sin(theta) * (gamma / 2*pi*f) * Slope * (2 e /  hbar)
# ...

# %%
# Sample SSN140 FCB(4)/Pt(18) Trans
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN140 = r".\\SSN140\\DCscan"
stfmr = STFMR(folder=Folder_SSN140, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=18e-9, Width=20e-6, Length=60e-6)


# stfmr.analyze_traces(plot=True)
stfmr.DCScan(method="Average_fitparams", Meff=1.193529, Meff_err=0.0050972348761976725, resistivity_Pt=27e8, resistivity_CFB=170e8)
# stfmr.calculate_xiFMR(plot=True)
# Out:
# Intersection J_Pt x: -3.5909156719270614
# Intersection J_Pt error: 0.29069229446718686
# Intersection alpha y: 0.02051519971486453
# Intersection alpha error: 1.3332739589262189e-05
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# Using variables: mu0 = 1.2566370614359173e-06 T·m/A, Ms = 1200000.0 A/m, t_FM = 4e-09 m, theta = 45.0 degrees, f = 10000000000.0 Hz, mu0 Meff = 1.12 T, Hext = 0.09715891770693777 T, slope = 4.1455949823596035e-16 mT/mA (T/A)
# Slope = (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * theta_sh
# theta_sh = ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t) / sin(theta) * (gamma / 2*pi*f) * Slope * (2 e /  hbar)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.array([3, 5, 9, 13, 15, 18])

xi_pos = np.array([0.09068838083154655, 0.06611409898733571 , 0.03763569070072416 , 0.05282424110663856 ,  0.041610105879946215 , 0.016622153625024685])
xi_pos_err = np.array([0.0026890612756566993, 0.0021338447566591786, 0.004433042786650375, 0.001792128767712925,  0.0021775020317982277,  0.0030381126199016135])
xi_neg = np.array([0.08942100589974562 , 0.06351607518413765 , 0.0717415203368261 , 0.058033531817902266 , 0.02799671047224278 ,  0.04954796741788718 ])
xi_neg_err = np.array([0.0017544608363110265, 0.0007266441243901391, 0.005614151512085451, 0.005501892037815613, 0.003232783724030857, 0.002618081615091207])
xi_avg = (xi_pos + xi_neg)/2
avg_scatter = abs(xi_pos - xi_neg)/2
xi_avg_err = np.sqrt(xi_pos_err**2 + xi_neg_err**2 + avg_scatter**2)/2

x_cross = np.array([2.707133272445019, 1.0014198023808765, 1.5515045888113508, 5.85013658170398, 5.78229423483067, -3.5258475854575004 ])
x_cross_err = np.array([0.11853453151883547, 0.09379121815067658, 0.2682878437037507,0.3737240185950227 , 0.3838514740981998, 0.28542499316822145])
y_cross = np.array([0.016681530069558352, 0.017577229047369285, 0.019094687320922496, 0.017726531039797388,  0.020172381638705085 , 0.020515199714339093])
y_cross_err = np.array([ 9.746136111169283e-06, 5.9489758013864706e-06, 2.1727544799269168e-05, 3.239426596597049e-05, 1.7856646003874007e-05, 1.3332742970175534e-05])

plt.figure(figsize=(8, 6))
# plt.errorbar(t, xi_pos, xi_pos_err, fmt='o--', label=r'$\xi_{FMR}$ Positve field ', markersize=4, capsize=4)
# plt.errorbar(t, xi_neg, xi_neg_err, fmt= '^--', label=r'$\xi_{FMR}$ Negative field', markersize=4, capsize=4)
plt.errorbar(t, xi_avg, xi_avg_err, fmt= '^--', label=r'$\xi_{DL}$ Average', markersize=4, capsize=4)

# plt.legend()
plt.ylabel("$\\xi_{DL}$",fontsize=12)
plt.xlabel("$t_{Pt}$ (nm)", fontsize=12)
# plt.title("$\\xi_{DL}$ versus $t_{Pt}$",fontsize=14)
plt.grid(True)
plt.ylim(bottom=0)
plt.show()


plt.figure(figsize=(8, 6))
plt.errorbar(t, x_cross, x_cross_err, fmt='o--', label=r'$\xi_{FMR}$ Positve field ', markersize=4, capsize=4)
# plt.errorbar(t, y_cross, y_cross_err, fmt= '^--', label=r'$\xi_{FMR}$ Negative field', markersize=4, capsize=4)
plt.legend()
plt.ylabel("Offset in $J_{Pt}$")
plt.xlabel("Pt thickness (nm)")
plt.title("$\\xi_{FMR}$ versus $t_{Pt}$")
plt.grid(True)

plt.show()

plt.figure(figsize=(8, 6))
plt.errorbar(t, y_cross, y_cross_err, fmt= '^--', label=r'$\xi_{DL}$ Negative field', markersize=4, capsize=4)
plt.legend()
plt.ylabel("Offset in $\\alpha$")
plt.xlabel("$t_{Pt}$ (nm)")
plt.title("$\\xi_{FMR}$ versus $t_{Pt}$")
plt.grid(True)

plt.show()
