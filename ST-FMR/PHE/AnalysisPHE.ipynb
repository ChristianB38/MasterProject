# %%
import os
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

plot=True

def phe_model(phi, R0, Rphe, phi0):
    return Rphe * np.sin(2 * (phi + phi0)) + R0

# Root directory containing sample folders
root_dir = "."

# Regex to extract field and current from filename
pattern = re.compile(
    r"PHE_field_(?P<field>[0-9.]+)deg_I_in_(?P<current>[0-9.]+)mAtrace(?P<trace>[0-9]+)"
)

all_results = []

for sample in os.listdir(root_dir):

    sample_path = os.path.join(root_dir, sample)

    if not os.path.isdir(sample_path):
        continue

    print(f"\nProcessing sample: {sample}")

    for file in os.listdir(sample_path):

        match = pattern.match(file)
        if not match:
            continue

        field = float(match.group("field"))
        current = float(match.group("current"))
        trace = int(match.group("trace"))

        filepath = os.path.join(sample_path, file)

        try:

            # Read data (skip "R=100")
            df = pd.read_csv(filepath, sep="\t", skiprows=1)
            df.columns = [c.strip() for c in df.columns]

            angle_deg = df["Angle"].values
            phi = np.deg2rad(angle_deg) 
            angle_deg = np.rad2deg(phi)
            Rxx = df["Rxx (ohm)"].values

            # Initial guesses
            guess_R0 = np.mean(Rxx)
            guess_dR = (np.max(Rxx) - np.min(Rxx)) / 2
            guess_phi0 = 0

            # Fit
            popt, pcov = curve_fit(
                phe_model,
                phi,
                Rxx,
                p0=[guess_R0, guess_dR, guess_phi0],
                bounds=([-np.inf, 0, -np.pi/2], [np.inf, np.inf, np.pi])
            )

            R0_fit, dR_fit, phi0_fit = popt

            phe_ratio = dR_fit / R0_fit

            # errors
            perr = np.sqrt(np.diag(pcov))

            R0_err = perr[0]
            dR_err = perr[1]
            phi0_err = perr[2]
            phe_ratio_err = np.sqrt(
                (dR_err / R0_fit)**2 +
                (dR_fit * R0_err / R0_fit**2)**2
            )

            # Store results
            all_results.append({
                "sample": sample,
                "file": file,
                "field_mT": field,
                "current_mA": current,
                "trace": trace,

                "R0_ohm": R0_fit,
                "R0_err": R0_err,

                "deltaR_ohm": dR_fit,
                "deltaR_err": dR_err,

                "phi0_rad": phi0_fit,
                "phi0_rad_err": phi0_err,

                "phi0_deg": np.rad2deg(phi0_fit),
                "phi0_deg_err": np.rad2deg(phi0_err),

                "phe_ratio": phe_ratio,
                "phe_ratio_err": phe_ratio_err
            })

            # Plot data + fit
            phi_fit = np.linspace(min(phi), max(phi), 500)
            if plot:
                plt.figure()
                plt.scatter(angle_deg, Rxx, s=10, label="data")

                plt.plot(
                    np.rad2deg(phi_fit),
                    phe_model(phi_fit, *popt),
                    label="phe fit"
                )

                plt.xlabel("Angle (deg)")
                plt.ylabel("Rxx (Ohm)")
                plt.title(f"{sample} | {field} mT | {current} mA")
                plt.legend()
                plt.tight_layout()

        except Exception as e:
            print(f"Error processing {filepath}: {e}")


# Convert results to DataFrame
results_df = pd.DataFrame(all_results)
# print(results_df["current_mA"], results_df["R0_ohm"], results_df["deltaR_ohm"], results_df["phi0_deg"])

# Save summary file
results_df.to_csv("PHE_fit_summary.csv", index=False)
print(results_df)
print("\nAnalysis finished. Results saved to phe_fit_summary.csv")
# Out:
# Processing sample: SSN092
#
# Processing sample: SSN093
#
# Processing sample: SSN094
#
# Processing sample: SSN139
#
# Processing sample: SSN140
#
# Processing sample: SSN141
#
# Processing sample: SSN142
#     sample                                         file  field_mT  current_mA  \
# 0   SSN092  PHE_field_197.256deg_I_in_3.000mAtrace1.txt   197.256         3.0
# 1   SSN092  PHE_field_197.562deg_I_in_9.000mAtrace1.txt   197.562         9.0
# 2   SSN092  PHE_field_197.634deg_I_in_6.000mAtrace1.txt   197.634         6.0
# 3   SSN093  PHE_field_197.313deg_I_in_3.000mAtrace1.txt   197.313         3.0
# 4   SSN093  PHE_field_197.564deg_I_in_9.000mAtrace1.txt   197.564         9.0
# 5   SSN093  PHE_field_197.628deg_I_in_6.000mAtrace1.txt   197.628         6.0
# 6   SSN094  PHE_field_197.283deg_I_in_3.000mAtrace1.txt   197.283         3.0
# 7   SSN094  PHE_field_197.531deg_I_in_6.000mAtrace1.txt   197.531         6.0
# 8   SSN094  PHE_field_197.615deg_I_in_9.000mAtrace1.txt   197.615         9.0
# 9   SSN139  PHE_field_197.360deg_I_in_3.000mAtrace1.txt   197.360         3.0
# 10  SSN139  PHE_field_197.575deg_I_in_6.000mAtrace1.txt   197.575         6.0
# 11  SSN139  PHE_field_197.672deg_I_in_9.000mAtrace1.txt   197.672         9.0
# 12  SSN141  PHE_field_197.323deg_I_in_3.000mAtrace1.txt   197.323         3.0
# 13  SSN141  PHE_field_197.710deg_I_in_9.000mAtrace1.txt   197.710         9.0
# 14  SSN141  PHE_field_197.730deg_I_in_6.000mAtrace1.txt   197.730         6.0
# 15  SSN142  PHE_field_197.385deg_I_in_3.000mAtrace1.txt   197.385         3.0
# 16  SSN142  PHE_field_197.626deg_I_in_9.000mAtrace1.txt   197.626         9.0
# 17  SSN142  PHE_field_197.729deg_I_in_6.000mAtrace1.txt   197.729         6.0
#
#     trace    R0_ohm    R0_err  deltaR_ohm  deltaR_err  phi0_rad  phi0_rad_err  \
# 0       1  0.047775  0.000062    0.005226    0.000089 -1.551548      0.008366
# 1       1  0.058572  0.000049    0.005320    0.000069 -1.542729      0.006437
# 2       1  0.055679  0.000054    0.005306    0.000076 -1.547693      0.007100
# 3       1 -0.031016  0.000054    0.005336    0.000077  1.558729      0.007162
# 4       1 -0.020838  0.000047    0.005273    0.000066  1.551389      0.006207
# 5       1 -0.023228  0.000053    0.005267    0.000075  1.554538      0.007058
# 6       1  0.034157  0.000042    0.005270    0.000059  1.559062      0.005535
# 7       1  0.041995  0.000046    0.005281    0.000066  1.558188      0.006171
# 8       1  0.044793  0.000041    0.005229    0.000058  1.562465      0.005506
# 9       1 -0.045010  0.000291    0.030045    0.000414 -1.553945      0.006796
# 10      1 -0.037111  0.000266    0.030020    0.000379 -1.552735      0.006223
# 11      1 -0.034490  0.000252    0.029951    0.000358 -1.553406      0.005903
# 12      1  0.020780  0.000162    0.016767    0.000230  1.563851      0.006768
# 13      1  0.031681  0.000144    0.016654    0.000206  1.562786      0.006089
# 14      1  0.028847  0.000154    0.016743    0.000219  1.562737      0.006463
# 15      1  0.080475  0.000066    0.007093    0.000094  1.553776      0.006560
# 16      1  0.091373  0.000058    0.006985    0.000083  1.554978      0.005858
# 17      1  0.088568  0.000058    0.007033    0.000083  1.556118      0.005823
#
#      phi0_deg  phi0_deg_err  phe_ratio  phe_ratio_err
# 0  -88.897134      0.479355   0.109391       0.001861
# 1  -88.391870      0.368792   0.090820       0.001187
# 2  -88.676297      0.406790   0.095287       0.001374
# 3   89.308579      0.410364  -0.172039       0.002516
# 4   88.888022      0.355616  -0.253055       0.003234
# 5   89.068489      0.404410  -0.226731       0.003285
# 6   89.327681      0.317110   0.154288       0.001741
# 7   89.277610      0.353561   0.125755       0.001579
# 8   89.522662      0.315455   0.116734       0.001307
# 9  -89.034474      0.389371  -0.667531       0.010157
# 10 -88.965148      0.356526  -0.808927       0.011736
# 11 -89.003609      0.338215  -0.868382       0.012172
# 12  89.602040      0.387765   0.806883       0.012724
# 13  89.541027      0.348879   0.525696       0.006917
# 14  89.538244      0.370320   0.580409       0.008212
# 15  89.024827      0.375852   0.088137       0.001174
# 16  89.093694      0.335618   0.076445       0.000909
# 17  89.159012      0.333620   0.079413       0.000939
#
# Analysis finished. Results saved to phe_fit_summary.csv

# %%
def weighted_mean_with_scatter(values, errors):

    values = np.array(values)
    errors = np.array(errors)

    weights = 1 / errors**2

    weighted_mean = np.sum(weights * values) / np.sum(weights)

    weighted_err = np.sqrt(1 / np.sum(weights))

    scatter = np.std(values, ddof=1)

    total_err = np.sqrt(weighted_err**2 + scatter**2)

    return weighted_mean, total_err, scatter


summary_rows = []

for sample in results_df["sample"].unique():

    df_sample = results_df[results_df["sample"] == sample]

    # R0
    R0_mean, R0_err, R0_scatter = weighted_mean_with_scatter(
        df_sample["R0_ohm"],
        df_sample["R0_err"]
    )

    # dR
    dR_mean, dR_err, dR_scatter = weighted_mean_with_scatter(
        df_sample["deltaR_ohm"],
        df_sample["deltaR_err"]
    )

    summary_rows.append({
        "sample": sample,

        "R0_mean": R0_mean,
        "R0_err": R0_err,
        "R0_scatter": R0_scatter,

        "dR_mean": dR_mean,
        "dR_err": dR_err,
        "dR_scatter": dR_scatter
    })

summary_df = pd.DataFrame(summary_rows)

summary_df.to_csv("phe_sample_summary.csv", index=False)

print(summary_df)
# Out:
#    sample   R0_mean    R0_err  R0_scatter   dR_mean    dR_err  dR_scatter
# 0  SSN092  0.054878  0.005589    0.005589  0.005291  0.000067    0.000050
# 1  SSN093 -0.024552  0.005322    0.005322  0.005289  0.000057    0.000038
# 2  SSN094  0.040239  0.005513    0.005513  0.005258  0.000045    0.000028
# 3  SSN139 -0.038359  0.005478    0.005476  0.030001  0.000226    0.000049
# 4  SSN141  0.027499  0.005657    0.005656  0.016717  0.000139    0.000059
# 5  SSN142  0.087322  0.005659    0.005659  0.007033  0.000073    0.000054

# %%
import pandas as pd
import matplotlib.pyplot as plt

thickness_map = {
    "SSN092": {"t_FM": 2e-9,"t_NM": 15e-9,"label": "pt15"},
    "SSN093": {"t_FM": 2.5e-9,"t_NM": 15e-9,"label": "pt15"},
    "SSN094": {"t_FM": 3e-9,"t_NM": 15e-9,"label": "pt15"},

    "SSN138": {"t_FM": 4e-9,"t_NM": 3e-9,"label": "CFB4"},
    "SSN101": {"t_FM": 4e-9,"t_NM": 5e-9,"label": "CFB4"},
    "SSN139": {"t_FM": 4e-9,"t_NM": 7e-9,"label": "CFB4"},
    "SSN140": {"t_FM": 4e-9,"t_NM": 18e-9,"label": "CFB4"},
    "SSN141": {"t_FM": 4e-9,"t_NM": 9e-9,"label": "CFB4"},
    "SSN142": {"t_FM": 4e-9,"t_NM": 13e-9,"label": "CFB4"},
    "SSN095": {"t_FM": 4e-9,"t_NM": 15e-9,"label": "CFB4"},
    "SSN143": {"t_FM": 4e-9,"t_NM": 13e-9,"label": "CFB4"},
}
# assuming your dataframe is called df
summary_df["t_NM"] = summary_df["sample"].map(lambda x: thickness_map[x]["t_NM"])
summary_df["t_NM_nm"] = summary_df["t_NM"] * 1e9
summary_df = summary_df.sort_values("t_NM_nm")


import matplotlib.pyplot as plt

# sort for nicer plotting
summary_df = summary_df.sort_values("t_NM_nm")

fig, ax1 = plt.subplots()

# --- Left axis: dR ---
ax1.errorbar(
    summary_df["t_NM_nm"],
    summary_df["dR_mean"],
    yerr=summary_df["dR_err"],
    fmt='o',
    capsize=4,
    label="$\\Delta R$",
    color='blue'
)
ax1.set_xlabel("$t_{NM}$ (nm)")
ax1.set_ylabel("$\\Delta R$ (Ohm)")
ax1.grid(True)

# --- Right axis: R0 ---
ax2 = ax1.twinx()

ax2.errorbar(
    summary_df["t_NM_nm"],
    summary_df["R0_mean"],
    yerr=summary_df["R0_err"],
    fmt='s',
    capsize=4,
    # linestyle='--',
    label="$R_0$",
    color='red',
    markersize=3
)
ax2.set_ylabel("$R_0$ (Ohm)")

# --- Optional: combine legends ---
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

ax1.legend(lines1 + lines2, labels1 + labels2, loc="best")

# plt.xlabel("$t_{NM}$ (nm)")
# plt.ylabel("$\\Delta R$")
plt.title("$\\Delta R$ versus $t_{NM}$ using $R(\\phi) = R_0 + \\Delta R cos(\\phi - \\phi_0)^2$")

# plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

thickness_map = {
    "SSN092": {"t_FM": 2e-9,"t_NM": 15e-9,"label": "pt15"},
    "SSN093": {"t_FM": 2.5e-9,"t_NM": 15e-9,"label": "pt15"},
    "SSN094": {"t_FM": 3e-9,"t_NM": 15e-9,"label": "pt15"},

    "SSN138": {"t_FM": 4e-9,"t_NM": 3e-9,"label": "CFB4"},
    "SSN101": {"t_FM": 4e-9,"t_NM": 5e-9,"label": "CFB4"},
    "SSN139": {"t_FM": 4e-9,"t_NM": 7e-9,"label": "CFB4"},
    "SSN140": {"t_FM": 4e-9,"t_NM": 18e-9,"label": "CFB4"},
    "SSN141": {"t_FM": 4e-9,"t_NM": 9e-9,"label": "CFB4"},
    "SSN142": {"t_FM": 4e-9,"t_NM": 13e-9,"label": "CFB4"},
    "SSN095": {"t_FM": 4e-9,"t_NM": 15e-9,"label": "CFB4"},
    "SSN143": {"t_FM": 4e-9,"t_NM": 13e-9,"label": "CFB4"},
}
# assuming your dataframe is called df
summary_df["t_NM"] = summary_df["sample"].map(lambda x: thickness_map[x]["t_NM"])
summary_df["t_NM_nm"] = summary_df["t_NM"] * 1e9
summary_df = summary_df.sort_values("t_NM_nm")


import matplotlib.pyplot as plt

# sort for nicer plotting
summary_df = summary_df.sort_values("t_NM_nm")

fig, ax1 = plt.subplots()

# --- Left axis: dR ---
ax1.errorbar(
    1/summary_df["t_NM_nm"],
    summary_df["dR_mean"],
    yerr=summary_df["dR_err"],
    fmt='o',
    capsize=4,
    label="$\\Delta R$ (Ohm)",
    color='blue',
    markersize=3

)
ax1.set_xlabel("1/$t_{NM}$ (nm)")
ax1.set_ylabel("$\\Delta R$")
ax1.grid(True)

# --- Right axis: R0 ---
ax2 = ax1.twinx()

ax2.errorbar(
    1/summary_df["t_NM_nm"],
    summary_df["R0_mean"],
    yerr=summary_df["R0_err"],
    fmt='s',
    capsize=4,
    # linestyle='--',
    label="$R_0$",
    color='red',
    markersize=3
)
ax2.set_ylabel("$R_0$ (Ohm)")

# --- Optional: combine legends ---
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

ax1.legend(lines1 + lines2, labels1 + labels2, loc="best")

# plt.xlabel("$t_{NM}$ (nm)")
# plt.ylabel("$\\Delta R$")
plt.title("$\\Delta R$ versus $t_{NM}$ using $R(\\phi) = R_0 + \\Delta R cos(\\phi - \\phi_0)^2$")

# plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

thickness_map = {
    "SSN092": {"t_FM": 2e-9,"t_NM": 15e-9,"label": "pt15"},
    "SSN093": {"t_FM": 2.5e-9,"t_NM": 15e-9,"label": "pt15"},
    "SSN094": {"t_FM": 3e-9,"t_NM": 15e-9,"label": "pt15"},

    "SSN138": {"t_FM": 4e-9,"t_NM": 3e-9,"label": "CFB4"},
    "SSN101": {"t_FM": 4e-9,"t_NM": 5e-9,"label": "CFB4"},
    "SSN139": {"t_FM": 4e-9,"t_NM": 7e-9,"label": "CFB4"},
    "SSN140": {"t_FM": 4e-9,"t_NM": 18e-9,"label": "CFB4"},
    "SSN141": {"t_FM": 4e-9,"t_NM": 9e-9,"label": "CFB4"},
    "SSN142": {"t_FM": 4e-9,"t_NM": 13e-9,"label": "CFB4"},
    "SSN095": {"t_FM": 4e-9,"t_NM": 15e-9,"label": "CFB4"},
    "SSN143": {"t_FM": 4e-9,"t_NM": 13e-9,"label": "CFB4"},
}
# assuming your dataframe is called df
summary_df["t_NM"] = summary_df["sample"].map(lambda x: thickness_map[x]["t_NM"])
summary_df["t_NM_nm"] = summary_df["t_NM"] * 1e9
summary_df = summary_df.sort_values("t_NM_nm")


import matplotlib.pyplot as plt

# sort for nicer plotting
summary_df = summary_df.sort_values("t_NM_nm")

fig, ax1 = plt.subplots()

# --- Left axis: dR ---
ax1.plot(
    summary_df["t_NM_nm"],
    summary_df["dR_mean"]/abs(summary_df["R0_mean"]),
    # yerr=summary_df["dR_err"],
    # fmt='o',
    # capsize=4,
    # label="$\\Delta R$ (Ohm)",
    # color='blue',

)
ax1.set_xlabel("1/$t_{NM}$ (nm)")
ax1.set_ylabel("$\\Delta R$")
ax1.grid(True)

# --- Right axis: R0 ---
# ax2 = ax1.twinx()

# ax2.errorbar(
#     1/summary_df["t_NM_nm"],
#     summary_df["R0_mean"],
#     yerr=summary_df["R0_err"],
#     fmt='s',
#     capsize=4,
#     # linestyle='--',
#     label="$R_0$",
#     color='red',
#     markersize=3
# )
# ax2.set_ylabel("$R_0$ (Ohm)")

# # --- Optional: combine legends ---
# lines1, labels1 = ax1.get_legend_handles_labels()
# lines2, labels2 = ax2.get_legend_handles_labels()

ax1.legend(lines1 + lines2, labels1 + labels2, loc="best")

# plt.xlabel("$t_{NM}$ (nm)")
# plt.ylabel("$\\Delta R$")
plt.title("$\\Delta R$ versus $t_{NM}$ using $R(\\phi) = R_0 + \\Delta R cos(\\phi - \\phi_0)^2$")

# plt.grid(True)
plt.show()
