# %%
# SSN095: power 0
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN095 = r".\\SSN095\\PowerScan2"
stfmr = STFMR(folder=Folder_SSN095, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=4e-9, d_NM=15e-9, Width=20e-6, Length=40e-6)

# stfmr.analyze_traces(plot=True)
# stfmr.average_fitparams(plot=True)
# stfmr.plot_averages()
stfmr.plot_power(method="Average_measurements")

# stfmr.calculate_xiFMR(plot=True)

# %%
# SSN095: power 0
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN095 = r".\\SSN095\\PowerScan3_10x40um"
stfmr = STFMR(folder=Folder_SSN095, voltage_unit='uV', used_fields='Pos', Ms=1.2, d_FM=4e-9, d_NM=15e-9, Width=20e-6, Length=40e-6)

# stfmr.analyze_traces(plot=True)

# stfmr.average_fitparams(plot=True)
# stfmr.plot_averages()
stfmr.plot_power(method="Average_fitparams")

# stfmr.calculate_xiFMR(plot=True)

# %%
# SSN095: power 0
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN095 = r".\\SSN095\\PowerScan15032026"
stfmr = STFMR(folder=Folder_SSN095, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=4e-9, d_NM=15e-9, Width=20e-6, Length=40e-6)

# stfmr.analyze_traces(plot=True)
# stfmr.average_fitparams(plot=True)
# stfmr.plot_averages()
stfmr.plot_power(method="Average_measurements")

# stfmr.calculate_xiFMR(plot=True)

# %%
# SSN095: power scan
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN095 = r".\\SSN101\\PowerScan15032026"
stfmr = STFMR(folder=Folder_SSN095, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=5e-9, d_NM=5e-9, Width=20e-6, Length=40e-6)

# stfmr.analyze_traces(plot=False)
# stfmr.average_fitparams(plot=False)
# stfmr.plot_averages()
# stfmr.plot_Kittel(plot=True)
stfmr.plot_power(method="Average_fitparams")

# stfmr.calculate_xiFMR(plot=True)

# %%
# Sample SSN097 FCB(10)/Pt(15), until freq=16
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module

importlib.reload(analysis_module)

from Analysis import STFMR, STFMR_thickness_analysis


thickness_map = {
    "Width10um_Length20um": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm", "Width": 10e-6, "Length": 20e-6, "R": 30.4},
    "Width10um_Length40um": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm", "Width": 10e-6, "Length": 40e-6, "R": 58.7},

    "Width15um_Length20um": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm", "Width": 15e-6, "Length": 20e-6, "R": 20.7},
    "Width15um_Length40um": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm", "Width": 15e-6, "Length": 40e-6, "R": 39.2},

    "Width20um_Length20um": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm", "Width": 20e-6, "Length": 20e-6, "R": 15.8},
    "Width20um_Length40um": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm", "Width": 20e-6, "Length": 40e-6, "R": 29.8},

    "Width25um_Length20um": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm", "Width": 25e-6, "Length": 20e-6, "R": 13},
    "Width20um_Length40um": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm", "Width": 25e-6, "Length": 40e-6, "R": 23.8},

    "Width30um_Length20um": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm", "Width": 30e-6, "Length": 20e-6, "R": 11.2},
    "Width30um_Length40um": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm", "Width": 30e-6, "Length": 40e-6, "R": 20.3},
}

voltage_unit='uV'
used_fields='Pos'
Ms=1.2e6
d_NM=5e-9
Width=20e-6
Length=40e-6

STFMR_ = STFMR_thickness_analysis(folder = r".\\SSN095\\Dimensions", voltage_unit=voltage_unit, d_FMs=thickness_map, d_NM=d_NM, Ms=Ms, Width=Width, Length=Length, group_name='CoFeB(t)/Pt(5) samples')

STFMR_.analyze_thickness_folder()
# STFMR_.plot_different_groups(title=' The damping factor versus $t_{CoFeB}$ for the three samples sets ') #$\\xi_{\\mathrm{FMR}}$ with $t_{\\mathrm{Pt}} = 5$ nm for different $t_{\\mathrm{CoFeB}}$
# STFMR_.plot_xi_inv_grouped(group_col="Label")

# STFMR_.plot_frequency(freq=8)
# STFMR_.plot_linewidths()
# STFMR_.plot_alpha()
# # STFMR_.plot_DeltaH0()

# STFMR_.plot_kittels()
# STFMR_.plot_Meff()
STFMR_.dimension_analysis()

# STFMR_.plot_xi_inv() #changes self.results
# Out:
# 0    Width10um_Length20um
# 1    Width10um_Length40um
# 2    Width15um_Length20um
# 3    Width15um_Length40um
# 4    Width20um_Length20um
# 5    Width20um_Length40um
# 6    Width25um_Length20um
# 7    Width30um_Length20um
# 8    Width30um_Length40um
# Name: Sample, dtype: object 0    1.139480
# 1    1.133696
# 2    1.115633
# 3    1.151449
# 4    1.113109
# 5    1.135350
# 6    1.126548
# 7    1.127997
# 8    1.132467
# Name: Meff, dtype: float64 0     [0.002276910620954397]
# 1    [0.0017454049975451252]
# 2    [0.0016181032915283135]
# 3    [0.0032332839090237334]
# 4    [0.0013391526849539008]
# 5    [0.0019450181147404528]
# 6    [0.0010120380412019926]
# 7    [0.0009327847618767872]
# 8    [0.0015412266000748853]
# Name: Meff_std, dtype: object
#                  Sample          t_FM          t_NM Label    Xi_fmr  \
# 0  Width10um_Length20um  5.000000e-09  1.500000e-08  15nm -0.113268
# 1  Width10um_Length40um  5.000000e-09  1.500000e-08  15nm -0.090484
# 2  Width15um_Length20um  5.000000e-09  1.500000e-08  15nm -0.086548
# 3  Width15um_Length40um  5.000000e-09  1.500000e-08  15nm -0.098256
# 4  Width20um_Length20um  5.000000e-09  1.500000e-08  15nm -0.084953
#
#    Xi_fmr_std      Meff                 Meff_std     Alpha  Alpha_std  \
# 0    0.004416  1.139480   [0.002276910620954397]  0.012527   0.000400
# 1    0.003921  1.133696  [0.0017454049975451252]  0.012624   0.000147
# 2    0.004355  1.115633  [0.0016181032915283135]  0.012818   0.000323
# 3    0.003027  1.151449  [0.0032332839090237334]  0.012027   0.000500
# 4    0.003771  1.113109  [0.0013391526849539008]  0.013618   0.000371
#
#        DeltaH0  DeltaH0_std               freq_  \
# 0  2062.661728   119.129842  [10.0, 11.0, 12.0]
# 1  2070.750707    44.590478  [10.0, 11.0, 12.0]
# 2  2100.397160    97.458865  [10.0, 11.0, 12.0]
# 3  2315.686135   151.922137  [10.0, 11.0, 12.0]
# 4  1391.981063   111.236758  [10.0, 11.0, 12.0]
#
#                                                  Vs_  \
# 0  [8.814998258136157, 5.775413941117797, 6.27326...
# 1  [9.445655127188305, 6.91186935715294, 8.078505...
# 2  [5.626391425469128, 3.676686840224408, 4.25214...
# 3  [7.026664027569362, 4.896885801767976, 5.38535...
# 4  [3.790987708806756, 2.4882154903562994, 2.7796...
#
#                                                  Va_  \
# 0  [-45.17769521333621, -29.085505234286543, -29....
# 1  [-64.40934012447732, -43.15142904508657, -44.4...
# 2  [-39.344699648269376, -23.89676415363218, -24....
# 3  [-43.77136913648441, -28.074613200847114, -28....
# 4  [-27.37674729137555, -16.237932119898367, -15....
#
#                                                Hres_     Width   Length     R
# 0  [0.09999536715677704, 0.11870735272099785, 0.1...  0.000010  0.00002  30.4
# 1  [0.1002219223981808, 0.11947304888938352, 0.14...  0.000010  0.00004  58.7
# 2  [0.10196978109948066, 0.12096960250201606, 0.1...  0.000015  0.00002  20.7
# 3  [0.09882316063459348, 0.11801388268143027, 0.1...  0.000015  0.00004  39.2
# 4  [0.10214454124896064, 0.12124638643530794, 0.1...  0.000020  0.00002  15.8
# 0    2.000000
# 1    4.000000
# 2    1.333333
# 3    2.666667
# 4    1.000000
# 5    1.600000
# 6    0.800000
# 7    0.666667
# 8    1.333333
# Name: aspectratio, dtype: float64                  Sample          t_FM          t_NM Label    Xi_fmr  \
# 0  Width10um_Length20um  5.000000e-09  1.500000e-08  15nm -0.113268
# 1  Width10um_Length40um  5.000000e-09  1.500000e-08  15nm -0.090484
# 2  Width15um_Length20um  5.000000e-09  1.500000e-08  15nm -0.086548
# 3  Width15um_Length40um  5.000000e-09  1.500000e-08  15nm -0.098256
# 4  Width20um_Length20um  5.000000e-09  1.500000e-08  15nm -0.084953
# 5  Width20um_Length40um  5.000000e-09  1.500000e-08  15nm -0.089287
# 6  Width25um_Length20um  5.000000e-09  1.500000e-08  15nm -0.083920
# 7  Width30um_Length20um  5.000000e-09  1.500000e-08  15nm -0.087397
# 8  Width30um_Length40um  5.000000e-09  1.500000e-08  15nm -0.085652
#
#    Xi_fmr_std      Meff                 Meff_std     Alpha  Alpha_std  \
# 0    0.004416  1.139480   [0.002276910620954397]  0.012527   0.000400
# 1    0.003921  1.133696  [0.0017454049975451252]  0.012624   0.000147
# 2    0.004355  1.115633  [0.0016181032915283135]  0.012818   0.000323
# 3    0.003027  1.151449  [0.0032332839090237334]  0.012027   0.000500
# 4    0.003771  1.113109  [0.0013391526849539008]  0.013618   0.000371
# 5    0.003677  1.135350  [0.0019450181147404528]  0.012852   0.000123
# 6    0.004543  1.126548  [0.0010120380412019926]  0.013602   0.000198
# 7    0.005728  1.127997  [0.0009327847618767872]  0.014094   0.000228
# 8    0.005229  1.132467  [0.0015412266000748853]  0.013470   0.000537
#
#        DeltaH0  DeltaH0_std               freq_  \
# 0  2062.661728   119.129842  [10.0, 11.0, 12.0]
# 1  2070.750707    44.590478  [10.0, 11.0, 12.0]
# 2  2100.397160    97.458865  [10.0, 11.0, 12.0]
# 3  2315.686135   151.922137  [10.0, 11.0, 12.0]
# 4  1391.981063   111.236758  [10.0, 11.0, 12.0]
# 5  2016.874326    37.082419  [10.0, 11.0, 12.0]
# 6  1973.874402    59.380228  [10.0, 11.0, 12.0]
# 7  1516.371826    67.281320  [10.0, 11.0, 12.0]
# 8  1727.348492   161.403672  [10.0, 11.0, 12.0]
#
#                                                  Vs_  \
# 0  [8.814998258136157, 5.775413941117797, 6.27326...
# 1  [9.445655127188305, 6.91186935715294, 8.078505...
# 2  [5.626391425469128, 3.676686840224408, 4.25214...
# 3  [7.026664027569362, 4.896885801767976, 5.38535...
# 4  [3.790987708806756, 2.4882154903562994, 2.7796...
# 5  [4.624370732099281, 3.2100583458081533, 3.5327...
# 6  [2.4824462656373205, 1.625077697404676, 1.7771...
# 7  [1.9517139322201789, 1.2874534987727062, 1.443...
# 8  [2.643603267177774, 1.878274435367059, 2.07537...
#
#                                                  Va_  \
# 0  [-45.17769521333621, -29.085505234286543, -29....
# 1  [-64.40934012447732, -43.15142904508657, -44.4...
# 2  [-39.344699648269376, -23.89676415363218, -24....
# 3  [-43.77136913648441, -28.074613200847114, -28....
# 4  [-27.37674729137555, -16.237932119898367, -15....
# 5  [-31.850302467695325, -19.968317817457777, -20...
# 6  [-18.400052389333155, -10.75639269709116, -10....
# 7  [-14.24628570623802, -8.230956579249034, -7.96...
# 8  [-19.98812489692644, -11.942732298124676, -11....
#
#                                                Hres_     Width   Length     R  \
# 0  [0.09999536715677704, 0.11870735272099785, 0.1...  0.000010  0.00002  30.4
# 1  [0.1002219223981808, 0.11947304888938352, 0.14...  0.000010  0.00004  58.7
# 2  [0.10196978109948066, 0.12096960250201606, 0.1...  0.000015  0.00002  20.7
# 3  [0.09882316063459348, 0.11801388268143027, 0.1...  0.000015  0.00004  39.2
# 4  [0.10214454124896064, 0.12124638643530794, 0.1...  0.000020  0.00002  15.8
# 5  [0.10012259323586464, 0.11946963925877492, 0.1...  0.000025  0.00004  23.8
# 6  [0.10091020718708069, 0.12016142166098412, 0.1...  0.000025  0.00002  13.0
# 7  [0.10078510388124282, 0.12008183977084588, 0.1...  0.000030  0.00002  11.2
# 8  [0.10040828334197152, 0.11970714513584883, 0.1...  0.000030  0.00004  20.3
#
#    aspectratio
# 0     2.000000
# 1     4.000000
# 2     1.333333
# 3     2.666667
# 4     1.000000
# 5     1.600000
# 6     0.800000
# 7     0.666667
# 8     1.333333
# c:\git\MasterProject\ST-FMR\Analysis.py:3356: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# SSN101: power scan
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN095 = r".\\SSN095\\PowerScan15032026"
stfmr = STFMR(folder=Folder_SSN095, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=15e-9, Width=20e-6, Length=40e-6, sample_name="Power Scan of Sub./CoFeB(4)/Pt(15)")

# stfmr.analyze_traces(plot=False)
# stfmr.average_fitparams(plot=True)
# stfmr.plot_averages()
# stfmr.plot_Kittel(plot=True)
stfmr.plot_power(method="Average_fitparams")

# stfmr.calculate_xiFMR(plot=True)
# Out:
# c:\git\MasterProject\ST-FMR\Analysis.py:1453: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   axes.set_xlim(left=0)

# %%
# SSN101: power scan
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN101 = r".\\SSN101\\PowerScan15032026"
stfmr = STFMR(folder=Folder_SSN101, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=5e-9, Width=20e-6, Length=40e-6,sample_name="Power Scan of Sub./CoFeB(4)/Pt(5)")

# stfmr.analyze_traces(plot=False)
# stfmr.average_fitparams(plot=False)
# stfmr.plot_averages()
# stfmr.plot_Kittel(plot=True)
stfmr.plot_power(method="Average_fitparams")

# stfmr.calculate_xiFMR(plot=True)
# Out:
# c:\git\MasterProject\ST-FMR\Analysis.py:1453: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   axes.set_xlim(left=0)

# %%
# SSN101: power scan
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN101 = r".\\SSN101\\PowerScan"
stfmr = STFMR(folder=Folder_SSN101, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=2e-9, d_NM=5e-9, Width=20e-6, Length=40e-6)

# stfmr.analyze_traces(plot=False)
# stfmr.average_fitparams(plot=False)
# stfmr.plot_averages()
# stfmr.plot_Kittel(plot=True)
stfmr.plot_power(method="Average_fitparams")

# stfmr.calculate_xiFMR(plot=True)
# Out:
# c:\git\MasterProject\ST-FMR\Analysis.py:1453: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   axes.set_xlim(left=0)

# %%
# SSN101: power scan
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN101 = r".\\SSN101\\PowerScan2"
stfmr = STFMR(folder=Folder_SSN101, voltage_unit='uV', used_fields='Pos', Ms=1e6, d_FM=5e-9, d_NM=5e-9, Width=20e-6, Length=40e-6)

# stfmr.analyze_traces(plot=True)
# stfmr.average_fitparams(plot=True)
# stfmr.plot_averages()
# stfmr.plot_Kittel(plot=True)
stfmr.plot_power(method="Average_fitparams")

# stfmr.calculate_xiFMR(plot=True)

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis
import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

thickness_map = {
    # "SSN092": {"t_FM": 2e-9,"t_NM": 15e-9,"label": "15nm"},
    # "SSN093": {"t_FM": 2.5e-9,"t_NM": 15e-9,"label": "15nm"},
    # "SSN094": {"t_FM": 3e-9,"t_NM": 15e-9,"label": "15nm"},
    "SSN095": {"t_FM": 4e-9,"t_NM": 15e-9,"label": "15nm"},
    # "DK159": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm"},
    # "SSN096": {"t_FM": 8e-9,"t_NM": 15e-9,"label": "15nm"},
    # "SSN097": {"t_FM": 10e-9,"t_NM": 15e-9,"label": "15nm"},

    # "SSN098": {"t_FM": 2e-9,"t_NM": 5e-9,"label": "5nm"},
    # "SSN099": {"t_FM": 2.5e-9,"t_NM": 5e-9,"label": "5nm"},
    # "SSN100": { "t_FM": 3e-9,"t_NM": 5e-9,"label": "5nm"},
    "SSN101": {"t_FM": 4e-9,"t_NM": 5e-9,"label": "5nm"},
    # "DK158": {"t_FM": 5e-9,"t_NM": 5e-9,"label": "5nm"},
    # "SSN102": {"t_FM": 8e-9,"t_NM": 5e-9,"label": "5nm"},
    # "SSN103": {"t_FM": 10e-9,"t_NM": 5e-9,"label": "5nm"},

    # "SSN121": {"t_FM": 2e-9,"t_NM": 15e-9,"label": "Mgo"},
    # "SSN122": {"t_FM": 2.5e-9,"t_NM": 15e-9,"label": "Mgo"},
    # "SSN123": {"t_FM": 3e-9,"t_NM": 15e-9,"label": "Mgo"},
    "SSN124": {"t_FM": 4e-9,"t_NM": 15e-9,"label": "Mgo"},
    # "DK161": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "Mgo"},
    # "SSN125": {"t_FM": 8e-9,"t_NM": 15e-9,"label": "Mgo"},
    # "SSN126": {"t_FM": 10e-9,"t_NM": 15e-9,"label": "Mgo"},
    
    "SSN145": {"t_FM": 4e-9,"t_NM": 0e-9,"label": "CFB"}
}


voltage_unit='uV'
used_fields='Pos'
Ms=1.2e6
d_NM=15e-9
Width=20e-6
Length=20e-6

STFMR_ = STFMR_thickness_analysis(folder = r".", voltage_unit=voltage_unit, d_FMs=thickness_map, d_NM=d_NM, Ms=Ms, Width=Width, Length=Length, group_name='Three sample groups')

STFMR_.analyze_thickness_folder()
STFMR_.plot_average_frequency(freq=11)

STFMR_.plot_different_groups()
# STFMR_.subtract_mgo_background()

# STFMR_.plot_linewidths()
# STFMR_.plot_alpha()
# STFMR_.plot_DeltaH0()

# STFMR_.plot_kittels()
# STFMR_.plot_Meff()

# STFMR_.plot_xi()
# STFMR_.plot_xi_inv(fit=False) #changes self.results
# Out:
# ⚠️ Skipping PowerScan.ipynb: no FrequencyScan folder.
# ⚠️ Skipping SSN095: no FrequencyScan folder.
# ⚠️ Skipping SSN101: no FrequencyScan folder.
# 🔍 Analyzing SSN095 (t_FM= 4e-09 nm)
# .\SSN095\FrequencyScan\Averaged_Traces_posB
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 51
#      48 STFMR_ = STFMR_thickness_analysis(folder = r".", voltage_unit=voltage_unit, d_FMs=thickness_map, d_NM=d_NM, Ms=Ms, Width=Width, Length=Length, group_name='Three sample groups')
#      50 STFMR_.analyze_thickness_folder()
# ---> 51 STFMR_.plot_average_frequency(freq=11)
#      53 STFMR_.plot_different_groups()
#      54 # STFMR_.subtract_mgo_background()
#      55
#      56 # STFMR_.plot_linewidths()
#    (...)     63 # STFMR_.plot_xi()
#      64 # STFMR_.plot_xi_inv(fit=False) #changes self.results
#
# File c:\git\MasterProject\ST-FMR\Analysis.py:2734, in STFMR_thickness_analysis.plot_average_frequency(self, freq, fit)
#    2723 stfmr = STFMR(
#    2724     folder=freq_path,
#    2725     voltage_unit=self.voltage_unit,
#    (...)   2731     used_fields=self.used_fields
#    2732 )
#    2733 if not os.path.exists(folder_path):
# -> 2734     stfmr.analyze_traces()
#    2735     continue
#    2736 try:
#
# File c:\git\MasterProject\ST-FMR\Analysis.py:344, in STFMR.analyze_traces(self, plot, folder)
#     342 print(output_folder)
#     343 # Create folder if not exists, and delete all files in them
# --> 344 os.mkdir(output_folder) if not os.path.exists(output_folder) else None
#     345 [os.remove(f.path) for f in os.scandir(output_folder) if f.is_file()]
#     347 # Collect files by (Phi, Freq, Pow, DC)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '.\\SSN095\\FrequencyScan\\Averaged_Traces_posB'
