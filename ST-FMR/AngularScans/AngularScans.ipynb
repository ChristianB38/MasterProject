# %%
# Sample SSN101 
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_DK158 = r".\\SSN101\\AngularScan_PHE_hallconfig\\"
stfmr = STFMR(folder=Folder_DK158, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=5e-9, Width=20e-6, Length=20e-6, sample_name="Sub./CoFeB(4)/Pt(5)")
# stfmr.average_fitparams(plot=False)

stfmr.transverse_scan()

# stfmr.plot_traces()
# stfmr.analyze_traces()
# stfmr.plot_Kittel(plot=True)
# stfmr.plot_linewidth(plot=True)

# %%
# Sample SSN101 
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_DK158 = r".\\SSN095\\Angular_transverse_halldevice\\"
stfmr = STFMR(folder=Folder_DK158, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=15e-9, Width=20e-6, Length=20e-6, sample_name="Sub./CoFeB(4)/Pt(15)")
# stfmr.average_fitparams(plot=False)

stfmr.transverse_scan()

# stfmr.plot_traces()
# stfmr.analyze_traces()
# stfmr.plot_Kittel(plot=True)
# stfmr.plot_linewidth(plot=True)

# %%
# Sample SSN138 FCB(4)/Pt(3)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_DK158 = r".\\SSN101\\AngularScan\\"
stfmr = STFMR(folder=Folder_DK158, voltage_unit='$\\mu$V', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=5e-9, Width=20e-6, Length=40e-6, sample_name="Sub.//CoFeB(4)/Pt(5)")
# stfmr.average_fitparams(plot=True)

stfmr.angular_scan()

# stfmr.plot_traces()
# stfmr.analyze_traces()
# stfmr.plot_Kittel(plot=True)
# stfmr.plot_linewidth(plot=True)
# Out:
# -48.14034694625367
# (18    6.495286
# 17    6.495300
# 16    6.495262
# 15    6.495161
# 14    6.495004
#         ...
# 50    6.494672
# 51    6.494897
# 52    6.495050
# 53    6.495179
# 54    6.495246
# Name: Hres, Length: 71, dtype: float64, 18    0.000524
# 17    0.000524
# 16    0.000523
# 15    0.000521
# 14    0.000517
#         ...
# 50    0.000509
# 51    0.000514
# 52    0.000518
# 53    0.000521
# 54    0.000523
# Name: Hres, Length: 71, dtype: float64)

# %%
# Sample SSN138 FCB(4)/Pt(3)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_DK158 = r".\\SSN101\\AngularScan_longitudinal_hallcontacts_xx\\"
stfmr = STFMR(folder=Folder_DK158, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=5e-9, Width=20e-6, Length=20e-6, sample_name="Sub.//CoFeB(4)/Pt(5)")
# stfmr.average_fitparams(plot=False)

stfmr.angular_scan()

# stfmr.plot_traces()
# stfmr.analyze_traces()
# stfmr.plot_Kittel(plot=True)
# stfmr.plot_linewidth(plot=True)
# Out:
# -22.93857529788613
# (18   -4.987016
# 17   -4.986754
# 16   -4.986641
# 15   -4.986527
# 14   -4.986400
#         ...
# 51   -4.987287
# 52   -4.987215
# 53   -4.987124
# 54   -4.986990
# 55   -4.986913
# Name: Hres, Length: 73, dtype: float64, 18    0.000264
# 17    0.000259
# 16    0.000257
# 15    0.000254
# 14    0.000252
#         ...
# 51    0.000270
# 52    0.000269
# 53    0.000267
# 54    0.000264
# 55    0.000262
# Name: Hres, Length: 73, dtype: float64)

# %%
# Sample SSN138 FCB(4)/Pt(3)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_DK158 = r".\\SSN095\\Angular_longitudinal"
stfmr = STFMR(folder=Folder_DK158, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=15e-9, Width=20e-6, Length=20e-6, sample_name="Sub./CoFeB(4)/Pt(15)")
# stfmr.average_fitparams(plot=False)

stfmr.angular_scan()

# stfmr.plot_traces()
# stfmr.analyze_traces()
# stfmr.plot_Kittel(plot=True)
# stfmr.plot_linewidth(plot=True)
# Out:
# -3.4568540530869734
# (18   -3.584485
# 17   -3.584390
# 16   -3.584364
# 15   -3.584346
# 14   -3.584310
#         ...
# 51   -3.584172
# 52   -3.584220
# 53   -3.584269
# 54   -3.584257
# 55   -3.584489
# Name: Hres, Length: 73, dtype: float64, 18    0.000196
# 17    0.000194
# 16    0.000193
# 15    0.000193
# 14    0.000192
#         ...
# 51    0.000189
# 52    0.000190
# 53    0.000191
# 54    0.000191
# 55    0.000196
# Name: Hres, Length: 73, dtype: float64)
