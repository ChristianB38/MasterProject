# %%
# Sample SSN139 FCB(4)/Pt(7)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN139 = r".\\SSN139\\DCscan_long_xx"
stfmr = STFMR(folder=Folder_SSN139, voltage_unit='uV', used_fields='Neg', Ms=1.2e6, d_FM=4e-9, d_NM=7e-9, Width=20e-6, Length=40e-6)

# stfmr.average_fitparams(plot=True)


# stfmr.analyze_traces(plot=True)
# stfmr.average_fitparams(plot=True)
stfmr.DCScan(method="Average_fitparams")
# stfmr.calculate_xiFMR(plot=True)
# Out:
# ----- Analysis of FMR efficiency ----- Paper DOI: https://doi-org.proxy-ub.rug.nl/10.1063/1.4999948
# theta'_SH = [ (mu0 * Ms * t_Py) / cos(theta) ] * [ (2 * e) / hbar ] * [ gamma / (4 * pi * f) ] * [ H_ext + 1/2 * H_perp ] * (dDelta / dJc)_Slope
# Using variables: mu0 = 1.2566370614359173e-06 , Ms = 1200000.0, t_FM = 4e-09 m, theta = 45.0, f = 10.0, H_per = 1.12 T, Hext = 100.3915090400976 mT, slope = 9.067959254135668e-16
# Slope, d(ΔH)/dJc =  9.067959254135668e-16 T⋅m2/A, Δα/Jc =  1.2706451332919202e-15 /(A/m2), or 0.00012706451332919203 x10^11 / (A/m2)
# theta_sh =  0.017300948887126796
#
#
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# ...

# %%
# Sample SSN141 FCB(4)/Pt(9)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN141 = r".\\SSN141\\Dcscan"
stfmr = STFMR(folder=Folder_SSN141, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=9e-9, Width=20e-6, Length=60e-6)


# stfmr.analyze_traces(plot=True)
stfmr.DCScan(method="Average_fitparams")
# stfmr.calculate_xiFMR(plot=True)
# Out:
# ----- Analysis of FMR efficiency ----- Paper DOI: https://doi-org.proxy-ub.rug.nl/10.1063/1.4999948
# theta'_SH = [ (mu0 * Ms * t_Py) / cos(theta) ] * [ (2 * e) / hbar ] * [ gamma / (4 * pi * f) ] * [ H_ext + 1/2 * H_perp ] * (dDelta / dJc)_Slope
# Using variables: mu0 = 1.2566370614359173e-06 , Ms = 1200000.0, t_FM = 4e-09 m, theta = 45.0, f = 10.0, H_per = 1.12 T, Hext = 101.00403463629705 mT, slope = 1.0417282595316073e-15
# Slope, d(ΔH)/dJc =  1.0417282595316073e-15 T⋅m2/A, Δα/Jc =  1.4597186710811564e-15 /(A/m2), or 0.00014597186710811565 x10^11 / (A/m2)
# theta_sh =  0.01989378584007927
#
#
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# ...

# %%
# Sample SSN141 FCB(4)/Pt(9)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN141 = r".\\SSN141\\Dcscan_Transverse"
stfmr = STFMR(folder=Folder_SSN141, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=9e-9, Width=20e-6, Length=60e-6)


# stfmr.analyze_traces(plot=True)
stfmr.DCScan(method="Average_fitparams")
# stfmr.calculate_xiFMR(plot=True)
# Out:
# .\\SSN141\\Dcscan_Transverse\fit_results_average_posB.csv
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-10.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-12.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-14.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-16.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-18.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-2.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-20.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-4.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-6.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-8.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_0.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_10.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_12.00mA_Trace_1.txt
# ...

# %%
# Sample SSN141 FCB(4)/Pt(9)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN141 = r".\\SSN141\\DcscanTransverse"
stfmr = STFMR(folder=Folder_SSN141, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=9e-9, Width=20e-6, Length=60e-6)


# stfmr.analyze_traces(plot=True)
stfmr.DCScan(method="Average_fitparams")
# stfmr.calculate_xiFMR(plot=True)
# Out:
# .\\SSN141\\DcscanTransverse\fit_results_average_posB.csv
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-10.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-12.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-14.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-16.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-18.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-2.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-20.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-4.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-6.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_-8.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_0.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_10.00mA_Trace_1.txt
# DCscan_Phi_45.0deg_Freq_10.0GHz_Pow_0.0dBm_Curr_12.00mA_Trace_1.txt
# ...

# %%
# Sample SSN143 FCB(4)/Pt(13)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN143 = r".\\SSN143\\DCscan_long_xx"
stfmr = STFMR(folder=Folder_SSN143, voltage_unit='uV', used_fields='Neg', Ms=1.2e6, d_FM=4e-9, d_NM=13e-9, Width=20e-6, Length=60e-6)

# stfmr.average_fitparams(plot=True)


# stfmr.analyze_traces(plot=True)
# stfmr.average_fitparams(plot=True)
stfmr.DCScan(method="Average_fitparams")
# stfmr.calculate_xiFMR(plot=True)
# Out:
# ----- Analysis of FMR efficiency ----- Paper DOI: https://doi-org.proxy-ub.rug.nl/10.1063/1.4999948
# theta'_SH = [ (mu0 * Ms * t_Py) / cos(theta) ] * [ (2 * e) / hbar ] * [ gamma / (4 * pi * f) ] * [ H_ext + 1/2 * H_perp ] * (dDelta / dJc)_Slope
# Using variables: mu0 = 1.2566370614359173e-06 , Ms = 1200000.0, t_FM = 4e-09 m, theta = 45.0, f = 10.0, H_per = 1.12 T, Hext = 100.3915089803966 mT, slope = 1.5886621231950141e-15
# Slope, d(ΔH)/dJc =  1.5886621231950141e-15 T⋅m2/A, Δα/Jc =  2.2261081448533296e-15 /(A/m2), or 0.00022261081448533295 x10^11 / (A/m2)
# theta_sh =  0.03031041651107016
#
#
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# ...

# %%
# Sample SSN140 FCB(4)/Pt(18)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis

Folder_SSN140 = r".\\SSN140\\DCscan"
stfmr = STFMR(folder=Folder_SSN140, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=18e-9, Width=20e-6, Length=60e-6)

# stfmr.average_fitparams(plot=True)


# stfmr.analyze_traces(plot=True)
# stfmr.average_fitparams(plot=True)
stfmr.DCScan(method="Average_measurements")
# stfmr.calculate_xiFMR(plot=True)
# Out:
# ----- Analysis of FMR efficiency ----- Paper DOI: https://doi-org.proxy-ub.rug.nl/10.1063/1.4999948
# theta'_SH = [ (mu0 * Ms * t_Py) / cos(theta) ] * [ (2 * e) / hbar ] * [ gamma / (4 * pi * f) ] * [ H_ext + 1/2 * H_perp ] * (dDelta / dJc)_Slope
# Using variables: mu0 = 1.2566370614359173e-06 , Ms = 1200000.0, t_FM = 4e-09 m, theta = 45.0, f = 10.0, H_per = 1.12 T, Hext = 97.13474308471262 mT, slope = 3.11820547210293e-16
# Slope, d(ΔH)/dJc =  3.11820547210293e-16 T⋅m2/A, Δα/Jc =  4.3693762804732426e-16 /(A/m2), or 4.369376280473243e-05 x10^11 / (A/m2)
# theta_sh =  0.005919950030408899
#
#
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# ...

# %%
# Sample SSN101 FCB(4)/Pt(5)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis
Folder_SSN095 = r".\\SSN101\\transverse_DCbias_25012026"
stfmr = STFMR(folder=Folder_SSN095, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=15e-9, Width=20e-6, Length=40e-6)



# stfmr.analyze_traces(plot=True)
# stfmr.average_fitparams(plot=True)
stfmr.DCScan(method='Average_measurements')
# stfmr.calculate_xiFMR(plot=True)
# Out:
# ----- Analysis of FMR efficiency ----- Paper DOI: https://doi-org.proxy-ub.rug.nl/10.1063/1.4999948
# theta'_SH = [ (mu0 * Ms * t_Py) / cos(theta) ] * [ (2 * e) / hbar ] * [ gamma / (4 * pi * f) ] * [ H_ext + 1/2 * H_perp ] * (dDelta / dJc)_Slope
# Using variables: mu0 = 1.2566370614359173e-06 , Ms = 1000000.0, t_FM = 4e-09 m, theta = 45.0, f = 10.0, H_per = 1.12 T, Hext = 103.28464107878023 mT, slope = 4.934203628011569e-15
# Slope, d(ΔH)/dJc =  4.934203628011569e-15 T⋅m2/A, Δα/Jc =  6.914038375001321e-15 /(A/m2), or 0.0006914038375001321 x10^11 / (A/m2)
# theta_sh =  0.0787942716802887
#
#
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# ...

# %%
# Sample SSN101 FCB(4)/Pt(5)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))
from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import STFMR, STFMR_thickness_analysis
Folder_SSN095 = r".\\SSN141\\Dcscan"
stfmr = STFMR(folder=Folder_SSN095, voltage_unit='uV', used_fields='Pos', Ms=1.2e6, d_FM=4e-9, d_NM=9e-9, Width=20e-6, Length=40e-6)



# stfmr.analyze_traces(plot=True)
# stfmr.average_fitparams(plot=True)
stfmr.DCScan(method='Average_measurements')
# stfmr.calculate_xiFMR(plot=True)
# Out:
# ----- Analysis of FMR efficiency ----- Paper DOI: https://doi-org.proxy-ub.rug.nl/10.1063/1.4999948
# theta'_SH = [ (mu0 * Ms * t_Py) / cos(theta) ] * [ (2 * e) / hbar ] * [ gamma / (4 * pi * f) ] * [ H_ext + 1/2 * H_perp ] * (dDelta / dJc)_Slope
# Using variables: mu0 = 1.2566370614359173e-06 , Ms = 1000000.0, t_FM = 4e-09 m, theta = 45.0, f = 10.0, H_per = 1.12 T, Hext = 100.98355230943902 mT, slope = 1.1027170898364392e-15
# Slope, d(ΔH)/dJc =  1.1027170898364392e-15 T⋅m2/A, Δα/Jc =  1.5451790908295775e-15 /(A/m2), or 0.00015451790908295774 x10^11 / (A/m2)
# theta_sh =  0.0027940451675744953
#
#
# ----- Analysis of FMR efficiency 2----- Paper DOI: file:///C:/Users/chris/Documents/DocumentsAndLiterature/Master%20Research%20Project/Literature/ST%20FMR/STFMR_for%20Report.pdf
# Delta_H = (2*pi*f/gamma) * alpha + (2*pi*f/gamma) * (sin(theta) / ((H_ext + 2*pi*M_eff) * mu_0 * M_s * t)) * (hbar / 2*e) * J_c * theta_sh
# ...

# %%
# Sample SSN097 FCB(10)/Pt(15)
from pathlib import Path
import sys

folder0_path = Path.cwd().parents[0]  # path to project_root
sys.path.append(str(folder0_path))

from Analysis import STFMR, STFMR_thickness_analysis

import importlib
import Analysis as analysis_module

importlib.reload(analysis_module)

from Analysis import STFMR, STFMR_thickness_analysis

thickness_map = {
    "SSN092": {"t_FM": 2e-9,"t_NM": 15e-9,"label": "15nm"},
    "SSN093": {"t_FM": 2.5e-9,"t_NM": 15e-9,"label": "15nm"},
    "SSN094": {"t_FM": 3e-9,"t_NM": 15e-9,"label": "15nm"},
    "SSN095": {"t_FM": 4e-9,"t_NM": 15e-9,"label": "15nm"},
    "DK159": {"t_FM": 5e-9,"t_NM": 15e-9,"label": "15nm"},
    "SSN096": {"t_FM": 8e-9,"t_NM": 15e-9,"label": "15nm"},
    "SSN097": {"t_FM": 10e-9,"t_NM": 15e-9,"label": "15nm"},
    }

voltage_unit='uV'
used_fields='Pos'
Ms=1.2e6
d_NM=15e-9
Width=20e-6
Length=20e-6

STFMR_ = STFMR_thickness_analysis(folder = r".", voltage_unit=voltage_unit, d_FMs=thickness_map, d_NM=d_NM, Ms=Ms, Width=Width, Length=Length)

STFMR_.analyze_thickness_folder()
STFMR_.plot_xi()

STFMR_.plot_frequency(freq=8)
# STFMR_.plot_linewidths()
# STFMR_.plot_alpha()
# STFMR_.plot_DeltaH0()

# STFMR_.plot_kittels()
STFMR_.plot_Meff()


STFMR_.plot_xi_inv() #changes self.results
# Out:
# ⚠️ Skipping Analysis_Pt15.ipynb: no FrequencyScan folder.
# 🔍 Analyzing DK159 (t_FM= 5e-09 nm)
# Sample: DK159 Vs 5.282760870371126 Va -40.00146954397808
# 🔍 Analyzing SSN092 (t_FM= 2e-09 nm)
# Sample: SSN092 Vs -0.89531193188953 Va -10.966225192589668
# 🔍 Analyzing SSN093 (t_FM= 2.5e-09 nm)
# c:\git\MasterProject\ST-FMR\Analysis.py:620: OptimizeWarning: Covariance of the parameters could not be estimated
#   params, pcov = curve_fit(self.Kittel_formula, abs(df_sorted['Hres']*1e-3), df_sorted['freq'], p0=[1e-3], sigma=df_sorted['Hresstd']*1e-3)
# c:\git\MasterProject\ST-FMR\Analysis.py:775: OptimizeWarning: Covariance of the parameters could not be estimated
#   params, pcov = curve_fit(self.linewidth_formula, df_sorted["freq"]*1e9, df_sorted['Delta']*1e-3, p0=[1/self.mu_0, 0.1], sigma=df_sorted['Deltastd']*1e-3)
# c:\git\MasterProject\ST-FMR\Analysis.py:620: OptimizeWarning: Covariance of the parameters could not be estimated
# ...
