# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\SSN145\\SecHarm"
folder1stHH = r".\\SSN145\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="SSN145: CoFeB(4)/MgO(2)/Ta(3)", R=734, Rxx=194.7, d_FM=4.0e-9, d_NM=0.0e-9, Ms=1e6, Width=20e-6)
results = hh.analyze_folder(plot_fits=False)
# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# c:\git\MasterProject\2ndHarmonicHall\Analysis.py:102: SyntaxWarning: invalid escape sequence '\s'
#   data = pd.read_csv(filepath, skiprows=5, sep='\s+')
# Calculated resistivity: 0.003894 Ohm·m
# Processing voltage: 1.0 V with files: ['2ndHH_HI_10.00A_U_1.00V_HG_556.72mT.txt', '2ndHH_HI_12.00A_U_1.00V_HG_650.65mT.txt', '2ndHH_HI_3.00A_U_1.00V_HG_175.85mT.txt', '2ndHH_HI_4.00A_U_1.00V_HG_231.90mT.txt', '2ndHH_HI_5.00A_U_1.00V_HG_287.23mT.txt', '2ndHH_HI_6.00A_U_1.00V_HG_342.32mT.txt', '2ndHH_HI_7.00A_U_1.00V_HG_397.14mT.txt', '2ndHH_HI_8.00A_U_1.00V_HG_451.61mT.txt']
# Processing voltage: 1.5 V with files: ['2ndHH_HI_10.00A_U_1.50V_HG_556.66mT.txt', '2ndHH_HI_12.00A_U_1.50V_HG_648.72mT.txt', '2ndHH_HI_3.00A_U_1.50V_HG_176.01mT.txt', '2ndHH_HI_4.00A_U_1.50V_HG_232.14mT.txt', '2ndHH_HI_5.00A_U_1.50V_HG_287.31mT.txt', '2ndHH_HI_6.00A_U_1.50V_HG_342.53mT.txt', '2ndHH_HI_7.00A_U_1.50V_HG_397.38mT.txt', '2ndHH_HI_8.00A_U_1.50V_HG_451.10mT.txt']
# ...

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\SSN147\\SecHarm"
folder1stHH = r".\\SSN147\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="SSN147: CoFeB(10)/MgO(2)/Ta(3)", R=336, Rxx=84.1, d_FM=10.0e-9, d_NM=0.0e-9, Ms=1e6, Width=20e-6)
results = hh.analyze_folder(plot_fits=False)
# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 0.0016820000000000001 Ohm·m
# Processing voltage: 1.0 V with files: ['2ndHH_HI_10.00A_U_1.00V_HG_555.80mT.txt', '2ndHH_HI_12.00A_U_1.00V_HG_648.96mT.txt', '2ndHH_HI_3.00A_U_1.00V_HG_175.74mT.txt', '2ndHH_HI_4.00A_U_1.00V_HG_231.53mT.txt', '2ndHH_HI_5.00A_U_1.00V_HG_286.85mT.txt', '2ndHH_HI_6.00A_U_1.00V_HG_341.65mT.txt', '2ndHH_HI_7.00A_U_1.00V_HG_396.39mT.txt', '2ndHH_HI_8.00A_U_1.00V_HG_450.43mT.txt', '2ndHH_HI_9.00A_U_1.00V_HG_502.83mT.txt']
# Processing voltage: 1.5 V with files: ['2ndHH_HI_10.00A_U_1.50V_HG_556.55mT.txt', '2ndHH_HI_12.00A_U_1.50V_HG_650.40mT.txt', '2ndHH_HI_3.00A_U_1.50V_HG_175.71mT.txt', '2ndHH_HI_4.00A_U_1.50V_HG_231.69mT.txt', '2ndHH_HI_5.00A_U_1.50V_HG_286.85mT.txt', '2ndHH_HI_6.00A_U_1.50V_HG_341.57mT.txt', '2ndHH_HI_7.00A_U_1.50V_HG_396.39mT.txt', '2ndHH_HI_8.00A_U_1.50V_HG_450.19mT.txt', '2ndHH_HI_9.00A_U_1.50V_HG_502.54mT.txt']
# ...

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\SSN097\\SecHarm"
folder1stHH = r".\\SSN097\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="SSN097: CoFeB(10)/Pt(15)", R=84, Rxx=8.4, d_FM=10e-9, d_NM=15.0e-9, Ms=1e6, Width=10e-6)
results = hh.analyze_folder(plot_fits=False)
# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 8.400000000000001e-05 Ohm·m
# Processing voltage: 0.5 V with files: ['Rxy_2ndHH_HI_1.00A_U_0.50V_HG_61.36mT.txt', 'Rxy_2ndHH_HI_10.00A_U_0.50V_HG_538.06mT.txt', 'Rxy_2ndHH_HI_12.00A_U_0.50V_HG_632.31mT.txt', 'Rxy_2ndHH_HI_2.00A_U_0.50V_HG_115.67mT.txt', 'Rxy_2ndHH_HI_3.00A_U_0.50V_HG_169.71mT.txt', 'Rxy_2ndHH_HI_4.00A_U_0.50V_HG_224.10mT.txt', 'Rxy_2ndHH_HI_5.00A_U_0.50V_HG_277.69mT.txt', 'Rxy_2ndHH_HI_6.00A_U_0.50V_HG_331.46mT.txt', 'Rxy_2ndHH_HI_8.00A_U_0.50V_HG_436.41mT.txt']
# Processing voltage: 1.5 V with files: ['Rxy_2ndHH_HI_1.00A_U_1.50V_HG_61.41mT.txt', 'Rxy_2ndHH_HI_10.00A_U_1.50V_HG_538.17mT.txt', 'Rxy_2ndHH_HI_12.00A_U_1.50V_HG_632.95mT.txt', 'Rxy_2ndHH_HI_2.00A_U_1.50V_HG_115.51mT.txt', 'Rxy_2ndHH_HI_3.00A_U_1.50V_HG_169.90mT.txt', 'Rxy_2ndHH_HI_4.00A_U_1.50V_HG_224.07mT.txt', 'Rxy_2ndHH_HI_5.00A_U_1.50V_HG_277.66mT.txt', 'Rxy_2ndHH_HI_6.00A_U_1.50V_HG_331.41mT.txt', 'Rxy_2ndHH_HI_8.00A_U_1.50V_HG_436.43mT.txt']
# ...
