# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\DK021\\SecHarm"
folder1stHH = r".\\DK021\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="DK021: ", R=880, Rxx=272.3, d_FM=5e-9, d_NM=3.0e-9, Ms=1e6, Width=10e-6, zerofield_correction=True)
hh.fit_1st_harm(plot=True)


results = hh.analyze_folder(plot_fits=False)
# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 0.002723 Ohm·m
# list [np.float64(0.11476701938923543)]
# Extracted Rphe: 0.11476701938923543 ± 0.0022842960517681565 Ohm
# Processing voltage: 2.0 V with files: ['SecHarm_HI_1.00A_U_2.00V_HG_64.41mT.txt', 'SecHarm_HI_10.00A_U_2.00V_HG_567.36mT.txt', 'SecHarm_HI_12.00A_U_2.00V_HG_659.71mT.txt', 'SecHarm_HI_2.00A_U_2.00V_HG_121.73mT.txt', 'SecHarm_HI_3.00A_U_2.00V_HG_179.17mT.txt', 'SecHarm_HI_4.00A_U_2.00V_HG_236.14mT.txt', 'SecHarm_HI_5.00A_U_2.00V_HG_292.59mT.txt', 'SecHarm_HI_6.00A_U_2.00V_HG_348.91mT.txt', 'SecHarm_HI_8.00A_U_2.00V_HG_459.84mT.txt']
# ...

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\DK074\\SecHarm"
folder1stHH = r".\\DK074\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="DK074: ", R=359, Rxx=107.4, d_FM=5e-9, d_NM=3.0e-9, Ms=1e6, Width=10e-6, zerofield_correction=True)
results = hh.analyze_folder(plot_fits=False)
hh.fit_1st_harm(plot=True)
# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 0.001074 Ohm·m
# Processing voltage: 2.5 V with files: ['SecHarm_HI_10.00A_U_2.50V_HG_564.27mT.txt', 'SecHarm_HI_12.00A_U_2.50V_HG_656.60mT.txt', 'SecHarm_HI_3.00A_U_2.50V_HG_178.29mT.txt', 'SecHarm_HI_4.00A_U_2.50V_HG_234.98mT.txt', 'SecHarm_HI_5.00A_U_2.50V_HG_291.71mT.txt', 'SecHarm_HI_6.00A_U_2.50V_HG_347.62mT.txt', 'SecHarm_HI_8.00A_U_2.50V_HG_458.20mT.txt']
# Processing voltage: 3.0 V with files: ['SecHarm_HI_10.00A_U_3.00V_HG_566.15mT.txt', 'SecHarm_HI_12.00A_U_3.00V_HG_659.22mT.txt', 'SecHarm_HI_3.00A_U_3.00V_HG_178.23mT.txt', 'SecHarm_HI_4.00A_U_3.00V_HG_235.09mT.txt', 'SecHarm_HI_5.00A_U_3.00V_HG_291.17mT.txt', 'SecHarm_HI_6.00A_U_3.00V_HG_347.65mT.txt', 'SecHarm_HI_8.00A_U_3.00V_HG_458.34mT.txt']
# ...

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\DK115\\SecHarm"
folder1stHH = r".\\DK115\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="SSN115:", R=2780, Rxx=834, d_FM=5e-9, d_NM=1e-9, Ms=1e6, Width=10e-6, zerofield_correction=True)
results = hh.analyze_folder(plot_fits=False)
hh.fit_1st_harm(plot=True)

# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 0.00834 Ohm·m
# Processing voltage: 2.0 V with files: ['SecHarm_HI_1.00A_U_2.00V_HG_64.44mT.txt', 'SecHarm_HI_10.00A_U_2.00V_HG_567.14mT.txt', 'SecHarm_HI_12.00A_U_2.00V_HG_658.18mT.txt', 'SecHarm_HI_2.00A_U_2.00V_HG_121.73mT.txt', 'SecHarm_HI_3.00A_U_2.00V_HG_179.09mT.txt', 'SecHarm_HI_4.00A_U_2.00V_HG_236.14mT.txt', 'SecHarm_HI_5.00A_U_2.00V_HG_292.64mT.txt', 'SecHarm_HI_6.00A_U_2.00V_HG_349.05mT.txt', 'SecHarm_HI_8.00A_U_2.00V_HG_459.60mT.txt']
# Processing voltage: 2.5 V with files: ['SecHarm_HI_1.00A_U_2.50V_HG_64.55mT.txt', 'SecHarm_HI_10.00A_U_2.50V_HG_566.50mT.txt', 'SecHarm_HI_12.00A_U_2.50V_HG_658.37mT.txt', 'SecHarm_HI_2.00A_U_2.50V_HG_121.78mT.txt', 'SecHarm_HI_3.00A_U_2.50V_HG_179.07mT.txt', 'SecHarm_HI_4.00A_U_2.50V_HG_235.90mT.txt', 'SecHarm_HI_5.00A_U_2.50V_HG_292.62mT.txt', 'SecHarm_HI_6.00A_U_2.50V_HG_348.67mT.txt', 'SecHarm_HI_8.00A_U_2.50V_HG_459.94mT.txt']
# ...

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\DK117\\SecHarm"
folder1stHH = r".\\DK117\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="SSN117:", R=658, Rxx=167.5, d_FM=5e-9, d_NM=1e-9, Ms=1e6, Width=10e-6, zerofield_correction=True)
hh.fit_1st_harm(plot=True)

results = hh.analyze_folder(plot_fits=False)

# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 0.001675 Ohm·m
# list [np.float64(0.17505766240804702)]
# Extracted Rphe: 0.17505766240804702 ± 0.0007049622746492901 Ohm
# Processing voltage: 2.0 V with files: ['SecHarm_HI_10.00A_U_2.00V_HG_565.59mT.txt', 'SecHarm_HI_12.00A_U_2.00V_HG_658.87mT.txt', 'SecHarm_HI_2.00A_U_2.00V_HG_121.83mT.txt', 'SecHarm_HI_3.00A_U_2.00V_HG_178.93mT.txt', 'SecHarm_HI_4.00A_U_2.00V_HG_235.84mT.txt', 'SecHarm_HI_5.00A_U_2.00V_HG_292.35mT.txt', 'SecHarm_HI_6.00A_U_2.00V_HG_348.94mT.txt', 'SecHarm_HI_8.00A_U_2.00V_HG_459.06mT.txt']
# Processing voltage: 2.5 V with files: ['SecHarm_HI_10.00A_U_2.50V_HG_567.63mT.txt', 'SecHarm_HI_12.00A_U_2.50V_HG_661.98mT.txt', 'SecHarm_HI_2.00A_U_2.50V_HG_121.83mT.txt', 'SecHarm_HI_3.00A_U_2.50V_HG_178.96mT.txt', 'SecHarm_HI_4.00A_U_2.50V_HG_235.84mT.txt', 'SecHarm_HI_5.00A_U_2.50V_HG_292.46mT.txt', 'SecHarm_HI_6.00A_U_2.50V_HG_349.10mT.txt', 'SecHarm_HI_8.00A_U_2.50V_HG_459.38mT.txt']
# ...
