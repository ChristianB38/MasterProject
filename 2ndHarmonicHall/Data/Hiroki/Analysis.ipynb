# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\DK231Si\\SecHarm"
folder1stHH = r".\\DK231Si\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="DK231Si", R=403, Rxx=70, d_FM=2.0e-9, d_NM=13.0e-9, Ms=1e6, Width=20e-6)

results = hh.analyze_folder(plot_fits=False)
# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 0.0014000000000000002 Ohm·m
# Processing voltage: 1.0 V with files: ['2ndHHtransverse_HI_10.00A_U_1.00V_HG_547.84mT.txt', '2ndHHtransverse_HI_12.00A_U_1.00V_HG_642.76mT.txt', '2ndHHtransverse_HI_3.00A_U_1.00V_HG_173.38mT.txt', '2ndHHtransverse_HI_4.00A_U_1.00V_HG_228.52mT.txt', '2ndHHtransverse_HI_5.00A_U_1.00V_HG_283.18mT.txt', '2ndHHtransverse_HI_6.00A_U_1.00V_HG_337.47mT.txt', '2ndHHtransverse_HI_7.00A_U_1.00V_HG_391.32mT.txt', '2ndHHtransverse_HI_8.00A_U_1.00V_HG_444.13mT.txt', '2ndHHtransverse_HI_9.00A_U_1.00V_HG_497.39mT.txt']
# Processing voltage: 1.5 V with files: ['2ndHHtransverse_HI_10.00A_U_1.50V_HG_547.90mT.txt', '2ndHHtransverse_HI_12.00A_U_1.50V_HG_642.12mT.txt', '2ndHHtransverse_HI_3.00A_U_1.50V_HG_172.74mT.txt', '2ndHHtransverse_HI_4.00A_U_1.50V_HG_227.88mT.txt', '2ndHHtransverse_HI_5.00A_U_1.50V_HG_282.49mT.txt', '2ndHHtransverse_HI_6.00A_U_1.50V_HG_337.01mT.txt', '2ndHHtransverse_HI_7.00A_U_1.50V_HG_390.60mT.txt', '2ndHHtransverse_HI_8.00A_U_1.50V_HG_443.75mT.txt', '2ndHHtransverse_HI_9.00A_U_1.50V_HG_497.12mT.txt']
# Processing voltage: 2.0 V with files: ['2ndHHtransverse_HI_10.00A_U_2.00V_HG_547.84mT.txt', '2ndHHtransverse_HI_12.00A_U_2.00V_HG_641.67mT.txt', '2ndHHtransverse_HI_3.00A_U_2.00V_HG_172.90mT.txt', '2ndHHtransverse_HI_4.00A_U_2.00V_HG_227.75mT.txt', '2ndHHtransverse_HI_5.00A_U_2.00V_HG_282.51mT.txt', '2ndHHtransverse_HI_6.00A_U_2.00V_HG_336.53mT.txt', '2ndHHtransverse_HI_7.00A_U_2.00V_HG_390.38mT.txt', '2ndHHtransverse_HI_8.00A_U_2.00V_HG_443.97mT.txt', '2ndHHtransverse_HI_9.00A_U_2.00V_HG_496.40mT.txt']
# Processing voltage: 2.5 V with files: ['2ndHHtransverse_HI_10.00A_U_2.50V_HG_548.78mT.txt', '2ndHHtransverse_HI_12.00A_U_2.50V_HG_639.65mT.txt', '2ndHHtransverse_HI_3.00A_U_2.50V_HG_172.85mT.txt', '2ndHHtransverse_HI_4.00A_U_2.50V_HG_227.72mT.txt', '2ndHHtransverse_HI_5.00A_U_2.50V_HG_282.43mT.txt', '2ndHHtransverse_HI_6.00A_U_2.50V_HG_336.98mT.txt', '2ndHHtransverse_HI_7.00A_U_2.50V_HG_390.49mT.txt', '2ndHHtransverse_HI_8.00A_U_2.50V_HG_444.05mT.txt', '2ndHHtransverse_HI_9.00A_U_2.50V_HG_495.84mT.txt']
# Processing voltage: 3.0 V with files: ['2ndHHtransverse_HI_10.00A_U_3.00V_HG_547.71mT.txt', '2ndHHtransverse_HI_12.00A_U_3.00V_HG_659.12mT.txt', '2ndHHtransverse_HI_3.00A_U_3.00V_HG_172.69mT.txt', '2ndHHtransverse_HI_4.00A_U_3.00V_HG_227.69mT.txt', '2ndHHtransverse_HI_5.00A_U_3.00V_HG_282.46mT.txt', '2ndHHtransverse_HI_6.00A_U_3.00V_HG_336.88mT.txt', '2ndHHtransverse_HI_7.00A_U_3.00V_HG_390.43mT.txt', '2ndHHtransverse_HI_8.00A_U_3.00V_HG_443.14mT.txt', '2ndHHtransverse_HI_9.00A_U_3.00V_HG_496.21mT.txt']
# 0    1.0
# 1    1.5
# 2    2.0
# 3    2.5
# 4    3.0
# Name: Voltage (V), dtype: float64 403
#    Voltage (V)      B_DL  B_DL_err   Thermal  Thermal_err      B_FL  B_FL_err  \
# 0          1.0 -0.000150  0.000071  0.000158     0.000062  0.000017  0.000008
# 1          1.5 -0.000071  0.000054  0.000100     0.000046  0.000009  0.000006
# 2          2.0 -0.000011  0.000041  0.000063     0.000035 -0.000005  0.000004
# 3          2.5  0.000012  0.000035  0.000059     0.000030 -0.000004  0.000004
# 4          3.0  0.000029  0.000036  0.000051     0.000031 -0.000002  0.000004
#
#    current_density      I_NM
# 0     9.441164e+09  0.002455
# 1     1.416175e+10  0.003682
# 2     1.888233e+10  0.004909
# 3     2.360291e+10  0.006137
# 4     2.832349e+10  0.007364
# list [np.float64(0.0017025993024815124), np.float64(0.0017973100032144926), np.float64(0.0011069347098578723), np.float64(0.001757044330500757), np.float64(0.0018561983371931277), np.float64(0.0017825277588846482), np.float64(0.0018166983640461431), np.float64(0.0017140944670149523), np.float64(0.0017307003328985216)]
# Extracted Rphe: 0.0016960119562324475 ± 4.628032878703139e-05 Ohm
# DL_efficiency by fit with Jc -0.0007262503622810688 ± 0.0017928869238053309
# FL_efficiency by fit with Jc 0.0040695441831272924
# DL_efficiency by fit with E -0.5187502449082312
# FL_efficiency by fit with E 2.9068353565462606

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\DK231SiN\\SecHarm"
folder1stHH = r".\\DK231SiN\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="DK231SiN", R=403, Rxx=70, d_FM=2.0e-9, d_NM=13.0e-9, Ms=1e6, Width=20e-6)

results = hh.analyze_folder(plot_fits=False)
# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 0.0014000000000000002 Ohm·m
# Processing voltage: 3.5 V with files: ['DK231SiN3degstep2nd10uV15000ws3tc_HI_0.50A_U_3.50V_HG_31.95mT.txt', 'DK231SiN3degstep2nd10uV15000ws3tc_HI_1.00A_U_3.50V_HG_57.47mT.txt', 'DK231SiN3degstep2nd5uV15000ws3tc_HI_1.00A_U_3.50V_HG_57.66mT.txt', 'DK231SiN3degstep2nd5uV15000ws3tc_HI_10.00A_U_3.50V_HG_507.74mT.txt', 'DK231SiN3degstep2nd5uV15000ws3tc_HI_11.00A_U_3.50V_HG_553.63mT.txt', 'DK231SiN3degstep2nd5uV15000ws3tc_HI_2.00A_U_3.50V_HG_108.75mT.txt', 'DK231SiN3degstep2nd5uV15000ws3tc_HI_3.00A_U_3.50V_HG_159.85mT.txt', 'DK231SiN3degstep2nd5uV15000ws3tc_HI_4.00A_U_3.50V_HG_210.97mT.txt', 'DK231SiN3degstep2nd5uV15000ws3tc_HI_5.00A_U_3.50V_HG_266.91mT.txt', 'DK231SiN3degstep2nd5uV15000ws3tc_HI_6.00A_U_3.50V_HG_311.62mT.txt', 'DK231SiN3degstep2nd5uV15000ws3tc_HI_7.00A_U_3.50V_HG_360.92mT.txt', 'DK231SiN3degstep2nd5uV15000ws3tc_HI_8.00A_U_3.50V_HG_410.03mT.txt', 'DK231SiN3degstep2nd5uV15000ws3tc_HI_9.00A_U_3.50V_HG_458.63mT.txt']
# Processing voltage: 2.5 V with files: ['DK231SiN3degstep2nd10uV15000ws3tc_HI_10.00A_U_2.50V_HG_505.94mT.txt', 'DK231SiN3degstep2nd10uV15000ws3tc_HI_6.00A_U_2.50V_HG_311.46mT.txt', 'DK231SiN3degstep2nd10uV15000ws3tc_HI_7.00A_U_2.50V_HG_361.08mT.txt', 'DK231SiN3degstep2nd10uV15000ws3tc_HI_8.00A_U_2.50V_HG_410.24mT.txt', 'DK231SiN3degstep2nd10uV15000ws3tc_HI_9.00A_U_2.50V_HG_458.71mT.txt']
# Processing voltage: 3.0 V with files: ['DK231SiN3degstep2nd10uV15000ws3tc_HI_10.00A_U_3.00V_HG_507.36mT.txt', 'DK231SiN3degstep2nd10uV15000ws3tc_HI_6.00A_U_3.00V_HG_311.60mT.txt', 'DK231SiN3degstep2nd10uV15000ws3tc_HI_7.00A_U_3.00V_HG_361.00mT.txt', 'DK231SiN3degstep2nd10uV15000ws3tc_HI_8.00A_U_3.00V_HG_410.65mT.txt', 'DK231SiN3degstep2nd10uV15000ws3tc_HI_9.00A_U_3.00V_HG_459.17mT.txt']
# 1    2.5
# 2    3.0
# 0    3.5
# Name: Voltage (V), dtype: float64 403
#    Voltage (V)      B_DL  B_DL_err   Thermal  Thermal_err          B_FL  \
# 1          2.5  0.000016  0.000250 -0.000059     0.000208 -8.114396e-06
# 2          3.0  0.000059  0.000251 -0.000105     0.000209 -7.088679e-06
# 0          3.5  0.000007  0.000046 -0.000068     0.000044 -8.197400e-07
#
#    B_FL_err  current_density      I_NM
# 1  0.000037     2.360291e+10  0.006137
# 2  0.000037     2.832349e+10  0.007364
# 0  0.000001     3.304407e+10  0.008591
# DL_efficiency by fit with Jc 0.0009064431868994319 ± 0.0005654075486850231
# FL_efficiency by fit with Jc -0.0082740897547038
# DL_efficiency by fit with E 0.6474594151200288
# FL_efficiency by fit with E -5.9100640993165054
