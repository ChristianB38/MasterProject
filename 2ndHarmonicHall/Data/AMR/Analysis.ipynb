# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH


folder2ndHH = r".\\noise"
folder1stHH = r".\\noise"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="SSN147: CoFeB(10)/MgO(2)/Ta(3)", R=1, Rxx=1, d_FM=10.0e-9, d_NM=0.0e-9, Ms=1e6, Width=20e-6)
hh.plot_folder()

# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 2e-05 Ohm·m
# Zerofield data found for V = 0.5
# Zerofield data found for V = 1.0
# Zerofield data found for V = 2.0
