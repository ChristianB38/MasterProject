# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\SSN122\\SecHarm"
folder1stHH = r".\\SSN122\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="SSN122: CoFeB(2.5)/Pt(15)", R=48, Rxx=7.4, d_FM=2.5e-9, d_NM=15.0e-9, Ms=1e6, Width=15e-6)
results = hh.analyze_folder(plot_fits=False)
# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# c:\git\MasterProject\2ndHarmonicHall\Analysis.py:102: SyntaxWarning: invalid escape sequence '\s'
#   data = pd.read_csv(filepath, skiprows=5, sep='\s+')
# Calculated resistivity: 0.00011100000000000001 Ohm·m
# Processing voltage: 1.5 V with files: ['Rxy_2ndHH_HI_1.00A_U_1.50V_HG_61.39mT.txt', 'Rxy_2ndHH_HI_10.00A_U_1.50V_HG_538.38mT.txt', 'Rxy_2ndHH_HI_12.00A_U_1.50V_HG_649.84mT.txt', 'Rxy_2ndHH_HI_2.00A_U_1.50V_HG_115.94mT.txt', 'Rxy_2ndHH_HI_3.00A_U_1.50V_HG_170.25mT.txt', 'Rxy_2ndHH_HI_4.00A_U_1.50V_HG_224.34mT.txt', 'Rxy_2ndHH_HI_5.00A_U_1.50V_HG_278.30mT.txt', 'Rxy_2ndHH_HI_6.00A_U_1.50V_HG_331.49mT.txt', 'Rxy_2ndHH_HI_7.00A_U_1.50V_HG_384.72mT.txt', 'Rxy_2ndHH_HI_8.00A_U_1.50V_HG_437.24mT.txt']
# ...

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\SSN123\\SecHarm"
folder1stHH = r".\\SSN123\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="SSN123: CoFeB(3)/MgO(2)/Pt(15)", R=76.7, Rxx=14.4, d_FM=3e-9, d_NM=15.0e-9, Ms=1e6, Width=15e-6)
results = hh.analyze_folder(plot_fits=False)
# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 0.00021600000000000002 Ohm·m
# Processing voltage: 1.5 V with files: ['Rxy_2ndHH_HI_1.00A_U_1.50V_HG_63.32mT.txt', 'Rxy_2ndHH_HI_10.00A_U_1.50V_HG_554.33mT.txt', 'Rxy_2ndHH_HI_12.00A_U_1.50V_HG_651.32mT.txt', 'Rxy_2ndHH_HI_2.00A_U_1.50V_HG_119.10mT.txt', 'Rxy_2ndHH_HI_3.00A_U_1.50V_HG_175.10mT.txt', 'Rxy_2ndHH_HI_4.00A_U_1.50V_HG_231.23mT.txt', 'Rxy_2ndHH_HI_5.00A_U_1.50V_HG_286.16mT.txt', 'Rxy_2ndHH_HI_6.00A_U_1.50V_HG_341.83mT.txt', 'Rxy_2ndHH_HI_7.00A_U_1.50V_HG_396.22mT.txt', 'Rxy_2ndHH_HI_8.00A_U_1.50V_HG_450.21mT.txt']
# ...

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\SSN123\\SecHarm"
folder1stHH = r".\\SSN123\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="SSN126: CoFeB(10)/MgO(2)/Pt(15)", R=67, Rxx=10.05, d_FM=10e-9, d_NM=15.0e-9, Ms=1e6, Width=10e-6, zerofield_correction=True)
results = hh.analyze_folder(plot_fits=False)
# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 0.00010050000000000002 Ohm·m
# Processing voltage: 1.0 V with files: ['Rxy_2ndHH_HI_1.00A_U_1.00V_HG_64.15mT.txt', 'Rxy_2ndHH_HI_10.00A_U_1.00V_HG_553.58mT.txt', 'Rxy_2ndHH_HI_12.00A_U_1.00V_HG_649.68mT.txt', 'Rxy_2ndHH_HI_2.00A_U_1.00V_HG_119.90mT.txt', 'Rxy_2ndHH_HI_3.00A_U_1.00V_HG_175.90mT.txt', 'Rxy_2ndHH_HI_4.00A_U_1.00V_HG_231.74mT.txt', 'Rxy_2ndHH_HI_5.00A_U_1.00V_HG_287.04mT.txt', 'Rxy_2ndHH_HI_6.00A_U_1.00V_HG_341.86mT.txt', 'Rxy_2ndHH_HI_7.00A_U_1.00V_HG_396.57mT.txt', 'Rxy_2ndHH_HI_8.00A_U_1.00V_HG_450.00mT.txt']
# ...

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder = r".\\SSN123\\SecHarm"

hh = HH(folder=folder, sample_name="SSN123: CoFeB(3)/MgO(2)/Pt(15)")
results = hh.extract_AD_and_FL_and_thermal_for_voltages()
# hh.plot_folder()
print(dict, results)
hh.plot_SOTs(results)
# Out:
# Processing voltage: 1.0 V with files: ['Rxy_2ndHH_HI_1.00A_U_1.00V_HG_64.15mT.txt', 'Rxy_2ndHH_HI_10.00A_U_1.00V_HG_553.58mT.txt', 'Rxy_2ndHH_HI_12.00A_U_1.00V_HG_649.68mT.txt', 'Rxy_2ndHH_HI_2.00A_U_1.00V_HG_119.90mT.txt', 'Rxy_2ndHH_HI_3.00A_U_1.00V_HG_175.90mT.txt', 'Rxy_2ndHH_HI_4.00A_U_1.00V_HG_231.74mT.txt', 'Rxy_2ndHH_HI_5.00A_U_1.00V_HG_287.04mT.txt', 'Rxy_2ndHH_HI_6.00A_U_1.00V_HG_341.86mT.txt', 'Rxy_2ndHH_HI_7.00A_U_1.00V_HG_396.57mT.txt', 'Rxy_2ndHH_HI_8.00A_U_1.00V_HG_450.00mT.txt']
# ...

# %%
from pathlib import Path
import sys
folder0_path = Path.cwd().parents[1]  # path to project_root
sys.path.append(str(folder0_path))

import importlib
import Analysis as analysis_module
importlib.reload(analysis_module)
from Analysis import HH



folder2ndHH = r".\\SSN126\\SecHarm"
folder1stHH = r".\\SSN126\\FirstHarm"

hh = HH(folder2nd=folder2ndHH, folder1st=folder1stHH, sample_name="SSN126: CoFeB(10)/MgO(2)/Pt(15)", R=67, Rxx=10.05, d_FM=10e-9, d_NM=15.0e-9, Ms=1e6, Width=10e-6)
results = hh.analyze_folder(plot_fits=False)
# hh.plot_folder()
# print(dict, results)
# hh.plot_SOTs(results)
# Out:
# Calculated resistivity: 0.00010050000000000002 Ohm·m
# Processing voltage: 1.5 V with files: ['Rxx_secondharmonicscans_HI_1.00A_U_1.50V_HG_63.37mT.txt', 'Rxx_secondharmonicscans_HI_10.00A_U_1.50V_HG_549.85mT.txt', 'Rxx_secondharmonicscans_HI_12.00A_U_1.50V_HG_646.81mT.txt', 'Rxx_secondharmonicscans_HI_2.00A_U_1.50V_HG_118.89mT.txt', 'Rxx_secondharmonicscans_HI_3.00A_U_1.50V_HG_174.21mT.txt', 'Rxx_secondharmonicscans_HI_4.00A_U_1.50V_HG_229.49mT.txt', 'Rxx_secondharmonicscans_HI_5.00A_U_1.50V_HG_284.82mT.txt', 'Rxx_secondharmonicscans_HI_6.00A_U_1.50V_HG_339.50mT.txt', 'Rxx_secondharmonicscans_HI_8.00A_U_1.50V_HG_446.62mT.txt']
# ...
